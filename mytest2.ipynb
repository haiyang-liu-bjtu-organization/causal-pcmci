# %%
import numpy as np
from scipy.integrate import odeint
from sklearn.metrics import roc_auc_score

def make_var_stationary(beta, radius=0.97):
    '''Rescale coefficients of VAR model to make stable.'''
    p = beta.shape[0]
    lag = beta.shape[1] // p
    bottom = np.hstack((np.eye(p * (lag - 1)), np.zeros((p * (lag - 1), p))))
    beta_tilde = np.vstack((beta, bottom))
    eigvals = np.linalg.eigvals(beta_tilde)
    max_eig = max(np.abs(eigvals))
    nonstationary = max_eig > radius
    if nonstationary:
        return make_var_stationary(0.95 * beta, radius)
    else:
        return beta


def simulate_var(p, T, lag, sparsity=0.2, beta_value=1.0, sd=0.1, seed=0):
    if seed is not None:
        np.random.seed(seed)

    # Set up coefficients and Granger causality ground truth.
    GC = np.eye(p, dtype=int)  # 生成一个对角线矩阵，对角线是1，其余全0．
    beta = np.eye(p) * beta_value  # 生成对角线为beta_value,其余为0的p阶方阵.

    num_nonzero = int(p * sparsity) - 1  # 非零个数为p×sparsity-1
    for i in range(p):  # 进行p个循环.
        choice = np.random.choice(p - 1, size=num_nonzero, replace=False)
        choice[choice >= i] += 1
        beta[i, choice] = beta_value
        GC[i, choice] = 1

    beta = np.hstack([beta for _ in range(lag)])
    beta = make_var_stationary(beta)

    # Generate data.
    burn_in = 100
    errors = np.random.normal(scale=sd, size=(p, T + burn_in))
    X = np.zeros((p, T + burn_in))
    X[:, :lag] = errors[:, :lag]
    for t in range(lag, T + burn_in):
        X[:, t] = np.dot(beta, X[:, (t-lag):t].flatten(order='F'))
        X[:, t] += + errors[:, t-1]

    return X.T[burn_in:], beta, GC


def lorenz(x, t, F):
    '''Partial derivatives for Lorenz-96 ODE.'''
    p = len(x)
    dxdt = np.zeros(p)
    for i in range(p):
        dxdt[i] = (x[(i+1) % p] - x[(i-2) % p]) * x[(i-1) % p] - x[i] + F

    return dxdt


def simulate_lorenz_96(p, T, F=10.0, delta_t=0.1, sd=0.1, burn_in=1000,
                       seed=0):
    if seed is not None:
        np.random.seed(seed)

    # Use scipy to solve ODE.
    x0 = np.random.normal(scale=0.01, size=p)
    t = np.linspace(0, (T + burn_in) * delta_t, T + burn_in)
    X = odeint(lorenz, x0, t, args=(F,))
    X += np.random.normal(scale=sd, size=(T + burn_in, p))

    # Set up Granger causality ground truth.
    GC = np.zeros((p, p), dtype=int)
    for i in range(p):
        GC[i, i] = 1
        GC[i, (i + 1) % p] = 1
        GC[i, (i - 1) % p] = 1
        GC[i, (i - 2) % p] = 1

    return X[burn_in:], GC

def compute_auroc(true_gc, p_matrix, tau_to_plot, alpha=0.05):
    # 这个地方GC是1为因果，pmatrix是0为因果，要把一个调过来
    # Flatten the matrices
    true_labels = true_gc.flatten()
    
    # Create estimated causal matrix based on p_matrix and alpha threshold
    # 要把一个调过来， 体现在这个地方 >即可
    estimated_gc = (p_matrix[:, :, tau_to_plot] > alpha).astype(int)

    # Flatten estimated labels
    estimated_labels = estimated_gc.flatten()

    # Remove self-loops (i.e., where i == j)
    mask = np.arange(len(true_labels)) % true_gc.shape[0] != np.arange(len(true_labels)) // true_gc.shape[0]
    true_labels = true_labels[mask]
    estimated_labels = estimated_labels[mask]

    # Calculate AUROC
    return roc_auc_score(true_labels, estimated_labels)

# %%
from tigramite.independence_tests.parcorr import ParCorr
import numpy as np
import matplotlib.pyplot as plt
from tigramite import data_processing as pp
from tigramite.pcmci import PCMCI
import tigramite.plotting as tp


# 定义参数
p = 10  # 维度
lengths = [200, 500, 1000]  # 不同的时间序列长度
lag = 5
seed = 981  # 随机种子

# 函数用于生成和分析数据
def analyze_data(X, var_names):
    # 创建 Tigramite 数据框
    dataframe = pp.DataFrame(X, var_names=var_names)

    # 绘制时间序列
    # tp.plot_timeseries(dataframe=dataframe)
    # plt.show()

    # 初始化部分相关性检验对象
    parcorr = ParCorr(significance='analytic')

    # 初始化 PCMCI 对象
    pcmci = PCMCI(
        dataframe=dataframe,
        cond_ind_test=parcorr,
        verbosity=1
    )

    # 运行 PCMCI 以获取滞后依赖关系
    tau_max = lag  # 设置最大滞后时间
    results = pcmci.run_pcmci(tau_max=tau_max, pc_alpha=0.05)  # 设置显著性水平 (alpha)

    # 绘制滞后相关性矩阵
    # tp.plot_lagfuncs(val_matrix=results['val_matrix'], setup_args={'var_names': var_names})
    # plt.show()

    # 提取因果图矩阵
    # graph = results['graph']
    # 
    # # 绘制因果图
    # tp.plot_graph(
    #     graph=graph,               # 因果图矩阵
    #     var_names=var_names,       # 变量名
    #     link_colorbar_label='MCI', # 链接颜色图例的标签
    # )
    # plt.show()

    # 提取 p 值矩阵
    p_matrix = results['p_matrix']


    # 绘制 p 值矩阵的灰度图像
    plt.figure(figsize=(8, 6))
    plt.imshow(p_matrix[:, :, tau_to_plot], cmap='gray', interpolation='none')
    plt.colorbar(label='p-value')
    plt.title(f'p-value matrix for tau={tau_to_plot}')
    plt.xlabel('Target variable (j)')
    plt.ylabel('Source variable (i)')
    plt.show()
    return results


# 设置你希望显示的滞后时间，假设选择第一个滞后时间（tau=1）
tau_to_plot = 1  # 选择滞后时间 tau = 1
# Analyze data and compute AUROC for different lengths
for T in lengths:
    # Generate VAR data
    X_var, beta_var, GC_var = simulate_var(p, T, lag, sparsity=0.2, beta_value=1.0, sd=0.1, seed=seed)
    var_names = [f'X{i}' for i in range(p)]
    print(f'Analyzing VAR data with T={T}')
    
    # Analyze VAR data
    results_var = analyze_data(X_var, var_names)
    
    # Compute AUROC for VAR
    auroc_var = compute_auroc(GC_var, results_var['p_matrix'], tau_to_plot)
    print(f'AUROC for VAR with T={T}: {auroc_var}')

    # Generate Lorenz-96 data
    X_lorenz, GC_lorenz = simulate_lorenz_96(p, T, F=10.0, delta_t=0.1, sd=0.1, burn_in=100, seed=seed)
    print(f'Analyzing Lorenz-96 data with T={T}')
    
    # Analyze Lorenz-96 data
    results_lorenz = analyze_data(X_lorenz, var_names)
    
    # Compute AUROC for Lorenz-96
    auroc_lorenz = compute_auroc(GC_lorenz, results_lorenz['p_matrix'], tau_to_plot)
    print(f'AUROC for Lorenz-96 with T={T}: {auroc_lorenz}')
    # 在循环的最后添加数据保存部分
    data_var_to_save = {
        'X_var': X_var,
        'GC_var': GC_var,
        'results_var': results_var,
        'auroc_var': auroc_var,
    }
    
    data_lorenz_to_save = {
        'X_lorenz': X_lorenz,
        'GC_lorenz': GC_lorenz,
        'results_lorenz': results_lorenz,
        'auroc_lorenz': auroc_lorenz,
    }
    
    # 生成文件名
    var_filename = f'results_var_T_{T}.npz'
    lorenz_filename = f'results_lorenz_T_{T}.npz'
    
    # 保存数据
    np.savez(var_filename, **data_var_to_save)
    np.savez(lorenz_filename, **data_lorenz_to_save)
    
    print(f'Saved VAR results to {var_filename}')
    print(f'Saved Lorenz-96 results to {lorenz_filename}')
# Out:
# Analyzing VAR data with T=200
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 5 link(s):
#         (X5 -3): max_pval = 0.01171, |min_val| =  0.185
#         (X3 -3): max_pval = 0.01355, |min_val| =  0.181
#         (X0 -2): max_pval = 0.01779, |min_val| =  0.174
#         (X5 -1): max_pval = 0.02830, |min_val| =  0.160
#         (X5 -2): max_pval = 0.03125, |min_val| =  0.158
#
#     Variable X1 has 5 link(s):
#         (X3 -1): max_pval = 0.00301, |min_val| =  0.216
#         (X1 -1): max_pval = 0.01615, |min_val| =  0.177
#         (X3 -3): max_pval = 0.01807, |min_val| =  0.174
#         (X1 -3): max_pval = 0.02240, |min_val| =  0.168
#         (X3 -5): max_pval = 0.04759, |min_val| =  0.146
#
#     Variable X2 has 3 link(s):
#         (X2 -4): max_pval = 0.00173, |min_val| =  0.228
#         (X2 -1): max_pval = 0.01110, |min_val| =  0.185
#         (X0 -4): max_pval = 0.01348, |min_val| =  0.180
#
#     Variable X3 has 5 link(s):
#         (X5 -1): max_pval = 0.00214, |min_val| =  0.223
#         (X0 -1): max_pval = 0.00710, |min_val| =  0.197
#         (X5 -2): max_pval = 0.01432, |min_val| =  0.179
#         (X3 -1): max_pval = 0.02211, |min_val| =  0.167
#         (X0 -2): max_pval = 0.02294, |min_val| =  0.167
#
#     Variable X4 has 4 link(s):
#         (X4 -4): max_pval = 0.00193, |min_val| =  0.226
#         (X9 -5): max_pval = 0.00557, |min_val| =  0.202
#         (X0 -4): max_pval = 0.00626, |min_val| =  0.200
#         (X4 -5): max_pval = 0.04274, |min_val| =  0.149
#
#     Variable X5 has 3 link(s):
#         (X4 -1): max_pval = 0.00098, |min_val| =  0.239
#         (X5 -3): max_pval = 0.01947, |min_val| =  0.171
#         (X5 -2): max_pval = 0.02295, |min_val| =  0.166
#
#     Variable X6 has 4 link(s):
#         (X3 -2): max_pval = 0.00182, |min_val| =  0.227
#         (X5 -2): max_pval = 0.00650, |min_val| =  0.199
#         (X8 -1): max_pval = 0.01082, |min_val| =  0.186
#         (X6 -3): max_pval = 0.01196, |min_val| =  0.184
#
#     Variable X7 has 5 link(s):
#         (X1 -3): max_pval = 0.00372, |min_val| =  0.212
#         (X7 -4): max_pval = 0.00727, |min_val| =  0.197
#         (X7 -3): max_pval = 0.01210, |min_val| =  0.184
#         (X1 -1): max_pval = 0.01431, |min_val| =  0.179
#         (X7 -2): max_pval = 0.04436, |min_val| =  0.148
#
#     Variable X8 has 5 link(s):
#         (X8 -1): max_pval = 0.00085, |min_val| =  0.243
#         (X8 -2): max_pval = 0.00185, |min_val| =  0.227
#         (X5 -1): max_pval = 0.01187, |min_val| =  0.185
#         (X6 -3): max_pval = 0.01212, |min_val| =  0.184
#         (X8 -5): max_pval = 0.02383, |min_val| =  0.166
#
#     Variable X9 has 3 link(s):
#         (X3 -2): max_pval = 0.00019, |min_val| =  0.271
#         (X9 -4): max_pval = 0.00105, |min_val| =  0.238
#         (X0 -5): max_pval = 0.01891, |min_val| =  0.172
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 5 link(s):
#         (X5 -1): pval = 0.01718 | val =  0.176
#         (X0 -2): pval = 0.01869 | val =  0.174
#         (X5 -3): pval = 0.02293 | val =  0.168
#         (X3 -3): pval = 0.02809 | val =  0.163
#         (X5 -2): pval = 0.03581 | val =  0.155
#
#     Variable X1 has 6 link(s):
#         (X3 -1): pval = 0.01053 | val =  0.190
#         (X8 -2): pval = 0.01764 | val = -0.177
#         (X6  0): pval = 0.01839 | val =  0.175 | unoriented link
#         (X3 -3): pval = 0.02733 | val =  0.164
#         (X2 -2): pval = 0.04052 | val = -0.152
#         (X3 -5): pval = 0.04468 | val =  0.149
#
#     Variable X2 has 3 link(s):
#         (X0 -4): pval = 0.01379 | val =  0.182
#         (X2 -1): pval = 0.01633 | val =  0.176
#         (X2 -4): pval = 0.04239 | val =  0.149
#
#     Variable X3 has 5 link(s):
#         (X5 -1): pval = 0.00622 | val =  0.202
#         (X7 -2): pval = 0.00813 | val =  0.197
#         (X1 -3): pval = 0.01967 | val = -0.174
#         (X2 -1): pval = 0.02072 | val = -0.171
#         (X0 -1): pval = 0.02193 | val =  0.170
#
#     Variable X4 has 6 link(s):
#         (X4 -4): pval = 0.00427 | val =  0.210
#         (X0 -4): pval = 0.00781 | val =  0.197
#         (X9 -5): pval = 0.02364 | val =  0.167
#         (X5 -4): pval = 0.02495 | val =  0.165
#         (X8 -4): pval = 0.04226 | val = -0.151
#         (X4 -5): pval = 0.04232 | val =  0.150
#
#     Variable X5 has 4 link(s):
#         (X4 -1): pval = 0.00150 | val =  0.232
#         (X9  0): pval = 0.01932 | val =  0.172 | unoriented link
#         (X5 -3): pval = 0.02536 | val =  0.164
#         (X5 -2): pval = 0.03569 | val =  0.155
#
#     Variable X6 has 5 link(s):
#         (X3 -2): pval = 0.00526 | val =  0.206
#         (X6 -3): pval = 0.00807 | val =  0.195
#         (X1  0): pval = 0.01839 | val =  0.175 | unoriented link
#         (X5 -2): pval = 0.01885 | val =  0.173
#         (X8 -1): pval = 0.02794 | val =  0.163
#
#     Variable X7 has 3 link(s):
#         (X1 -3): pval = 0.01257 | val =  0.185
#         (X7 -4): pval = 0.01644 | val =  0.178
#         (X7 -3): pval = 0.03572 | val =  0.156
#
#     Variable X8 has 5 link(s):
#         (X8 -2): pval = 0.00983 | val =  0.191
#         (X8 -1): pval = 0.01290 | val =  0.184
#         (X5 -1): pval = 0.01691 | val =  0.176
#         (X8 -5): pval = 0.01910 | val =  0.174
#         (X9 -5): pval = 0.03522 | val = -0.156
#
#     Variable X9 has 5 link(s):
#         (X3 -2): pval = 0.00186 | val =  0.229
#         (X9 -4): pval = 0.01571 | val =  0.177
#         (X5  0): pval = 0.01932 | val =  0.172 | unoriented link
#         (X6 -4): pval = 0.03219 | val = -0.158
#         (X0 -5): pval = 0.04429 | val =  0.149
# AUROC for VAR with T=200: 0.55
# Analyzing Lorenz-96 data with T=200
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 7 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.793
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.505
#         (X0 -3): max_pval = 0.00030, |min_val| =  0.260
#         (X1 -1): max_pval = 0.00099, |min_val| =  0.237
#         (X8 -1): max_pval = 0.00331, |min_val| =  0.214
#         (X3 -1): max_pval = 0.04358, |min_val| =  0.149
#         (X0 -4): max_pval = 0.04559, |min_val| =  0.145
#
#     Variable X1 has 6 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.733
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.360
#         (X0 -1): max_pval = 0.00204, |min_val| =  0.224
#         (X2 -1): max_pval = 0.00709, |min_val| =  0.196
#         (X0 -2): max_pval = 0.03093, |min_val| =  0.157
#         (X8 -3): max_pval = 0.04291, |min_val| =  0.149
#
#     Variable X2 has 4 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.878
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.602
#         (X2 -3): max_pval = 0.00000, |min_val| =  0.324
#         (X3 -1): max_pval = 0.00045, |min_val| =  0.254
#
#     Variable X3 has 5 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.835
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.496
#         (X3 -3): max_pval = 0.00527, |min_val| =  0.202
#         (X4 -1): max_pval = 0.01248, |min_val| =  0.182
#         (X1 -2): max_pval = 0.03171, |min_val| =  0.157
#
#     Variable X4 has 5 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.812
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.449
#         (X4 -3): max_pval = 0.00549, |min_val| =  0.201
#         (X5 -1): max_pval = 0.02706, |min_val| =  0.161
#         (X7 -4): max_pval = 0.03795, |min_val| =  0.152
#
#     Variable X5 has 4 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.730
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.385
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.361
#         (X6 -2): max_pval = 0.00088, |min_val| =  0.240
#
#     Variable X6 has 6 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.783
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.479
#         (X7 -1): max_pval = 0.00003, |min_val| =  0.299
#         (X8 -1): max_pval = 0.00400, |min_val| =  0.208
#         (X4 -1): max_pval = 0.00443, |min_val| =  0.207
#         (X6 -3): max_pval = 0.01492, |min_val| =  0.176
#
#     Variable X7 has 2 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.738
#         (X7 -2): max_pval = 0.00010, |min_val| =  0.279
#
#     Variable X8 has 3 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.769
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.380
#         (X4 -2): max_pval = 0.03950, |min_val| =  0.150
#
#     Variable X9 has 4 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.869
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.593
#         (X9 -3): max_pval = 0.00001, |min_val| =  0.324
#         (X6 -4): max_pval = 0.00057, |min_val| =  0.250
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 18 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.847
#         (X0 -2): pval = 0.00000 | val = -0.604
#         (X0 -3): pval = 0.00000 | val =  0.442
#         (X1 -1): pval = 0.00000 | val =  0.411
#         (X8 -1): pval = 0.00000 | val = -0.360
#         (X1 -2): pval = 0.00002 | val = -0.309
#         (X0 -4): pval = 0.00009 | val = -0.289
#         (X6 -1): pval = 0.00011 | val = -0.287
#         (X8  0): pval = 0.00013 | val = -0.281 | unoriented link
#         (X9 -1): pval = 0.00019 | val = -0.275
#         (X7  0): pval = 0.00025 | val =  0.269 | unoriented link
#         (X3 -3): pval = 0.00053 | val =  0.257
#         (X8 -2): pval = 0.00049 | val =  0.257
#         (X2 -2): pval = 0.00145 | val =  0.236
#         (X0 -5): pval = 0.00906 | val =  0.196
#         (X3 -1): pval = 0.03262 | val = -0.160
#         (X5 -1): pval = 0.03678 | val =  0.156
#         (X4 -3): pval = 0.04457 | val = -0.151
#
#     Variable X1 has 14 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.879
#         (X1 -2): pval = 0.00000 | val = -0.628
#         (X1 -3): pval = 0.00000 | val =  0.476
#         (X0 -1): pval = 0.00000 | val = -0.375
#         (X2  0): pval = 0.00000 | val = -0.339 | unoriented link
#         (X0 -2): pval = 0.00001 | val =  0.324
#         (X1 -4): pval = 0.00004 | val =  0.303
#         (X0 -3): pval = 0.00149 | val = -0.237
#         (X2 -3): pval = 0.00560 | val = -0.206
#         (X2 -1): pval = 0.01673 | val =  0.178
#         (X9 -1): pval = 0.01933 | val = -0.174
#         (X4 -1): pval = 0.02487 | val =  0.168
#         (X8 -3): pval = 0.02477 | val =  0.166
#         (X2 -4): pval = 0.04926 | val = -0.147
#
#     Variable X2 has 14 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.882
#         (X2 -2): pval = 0.00000 | val = -0.605
#         (X2 -3): pval = 0.00000 | val =  0.450
#         (X1  0): pval = 0.00000 | val = -0.339 | unoriented link
#         (X2 -4): pval = 0.00001 | val = -0.330
#         (X3 -2): pval = 0.00001 | val = -0.317
#         (X3 -1): pval = 0.00033 | val =  0.263
#         (X1 -1): pval = 0.00048 | val = -0.257
#         (X5  0): pval = 0.01633 | val = -0.178 | unoriented link
#         (X4 -4): pval = 0.01830 | val = -0.175
#         (X0 -2): pval = 0.02207 | val = -0.171
#         (X8 -2): pval = 0.02177 | val =  0.170
#         (X1 -4): pval = 0.04283 | val = -0.151
#         (X1 -5): pval = 0.04751 | val = -0.148
#
#     Variable X3 has 13 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.868
#         (X3 -2): pval = 0.00000 | val = -0.656
#         (X3 -3): pval = 0.00000 | val =  0.538
#         (X4 -1): pval = 0.00000 | val =  0.355
#         (X3 -4): pval = 0.00000 | val = -0.344
#         (X2 -1): pval = 0.00001 | val = -0.324
#         (X3 -5): pval = 0.00051 | val = -0.256
#         (X1 -2): pval = 0.00207 | val = -0.228
#         (X5 -2): pval = 0.00248 | val =  0.224
#         (X4 -3): pval = 0.00434 | val = -0.212
#         (X4 -2): pval = 0.00714 | val = -0.200
#         (X1 -4): pval = 0.03254 | val =  0.160
#         (X8 -2): pval = 0.04784 | val = -0.147
#
#     Variable X4 has 12 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.871
#         (X4 -2): pval = 0.00000 | val = -0.647
#         (X4 -3): pval = 0.00000 | val =  0.440
#         (X4 -4): pval = 0.00002 | val = -0.313
#         (X5 -3): pval = 0.00011 | val = -0.283
#         (X5 -1): pval = 0.00146 | val =  0.234
#         (X6  0): pval = 0.00256 | val = -0.224 | unoriented link
#         (X4 -5): pval = 0.00434 | val = -0.212
#         (X6 -5): pval = 0.00875 | val = -0.195
#         (X3 -1): pval = 0.00840 | val = -0.195
#         (X1 -2): pval = 0.03718 | val =  0.156
#         (X0 -4): pval = 0.04353 | val =  0.151
#
#     Variable X5 has 11 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.889
#         (X5 -2): pval = 0.00000 | val = -0.695
#         (X5 -3): pval = 0.00000 | val =  0.392
#         (X6 -1): pval = 0.00000 | val =  0.385
#         (X5 -4): pval = 0.00024 | val =  0.269
#         (X6  0): pval = 0.00282 | val = -0.220 | unoriented link
#         (X8 -4): pval = 0.00481 | val = -0.208
#         (X6 -2): pval = 0.01343 | val = -0.183
#         (X2  0): pval = 0.01633 | val = -0.178 | unoriented link
#         (X5 -5): pval = 0.02290 | val =  0.169
#         (X2 -5): pval = 0.03127 | val =  0.160
#
#     Variable X6 has 16 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.876
#         (X6 -2): pval = 0.00000 | val = -0.680
#         (X6 -3): pval = 0.00000 | val =  0.493
#         (X7 -1): pval = 0.00000 | val =  0.437
#         (X5 -1): pval = 0.00000 | val = -0.336
#         (X6 -4): pval = 0.00005 | val = -0.300
#         (X7 -2): pval = 0.00005 | val = -0.297
#         (X6 -5): pval = 0.00029 | val = -0.268
#         (X4  0): pval = 0.00256 | val = -0.224 | unoriented link
#         (X5  0): pval = 0.00282 | val = -0.220 | unoriented link
#         (X7 -3): pval = 0.00524 | val = -0.206
#         (X9 -1): pval = 0.00580 | val = -0.205
#         (X0 -2): pval = 0.01906 | val = -0.176
#         (X8 -2): pval = 0.02377 | val =  0.168
#         (X3 -2): pval = 0.03753 | val = -0.156
#         (X8 -4): pval = 0.04114 | val = -0.152
#
#     Variable X7 has 13 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.818
#         (X7 -2): pval = 0.00000 | val = -0.588
#         (X6 -1): pval = 0.00000 | val = -0.337
#         (X7 -3): pval = 0.00002 | val =  0.307
#         (X9  0): pval = 0.00007 | val = -0.290 | unoriented link
#         (X0  0): pval = 0.00025 | val =  0.269 | unoriented link
#         (X0 -2): pval = 0.00253 | val = -0.223
#         (X8 -2): pval = 0.00335 | val =  0.215
#         (X8 -4): pval = 0.01211 | val = -0.184
#         (X4 -4): pval = 0.01768 | val =  0.175
#         (X6 -3): pval = 0.02139 | val =  0.170
#         (X7 -4): pval = 0.03014 | val =  0.159
#         (X4 -5): pval = 0.04552 | val =  0.148
#
#     Variable X8 has 12 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.809
#         (X8 -2): pval = 0.00000 | val = -0.598
#         (X8 -3): pval = 0.00000 | val =  0.425
#         (X0  0): pval = 0.00013 | val = -0.281 | unoriented link
#         (X9 -2): pval = 0.00030 | val =  0.265
#         (X8 -4): pval = 0.00120 | val =  0.237
#         (X1 -5): pval = 0.00525 | val = -0.207
#         (X7 -4): pval = 0.00754 | val = -0.196
#         (X5 -3): pval = 0.02832 | val =  0.162
#         (X0 -4): pval = 0.03223 | val = -0.160
#         (X0 -5): pval = 0.04156 | val = -0.152
#         (X3 -2): pval = 0.04314 | val = -0.150
#
#     Variable X9 has 9 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.862
#         (X9 -2): pval = 0.00000 | val = -0.529
#         (X7  0): pval = 0.00007 | val = -0.290 | unoriented link
#         (X9 -3): pval = 0.00201 | val =  0.227
#         (X8 -2): pval = 0.01082 | val = -0.188
#         (X7 -1): pval = 0.01226 | val = -0.184
#         (X1 -3): pval = 0.02425 | val = -0.168
#         (X2 -4): pval = 0.02475 | val = -0.166
#         (X8 -1): pval = 0.03801 | val =  0.154
# AUROC for Lorenz-96 with T=200: 0.31666666666666665
# Saved VAR results to results_var_T_200.npz
# Saved Lorenz-96 results to results_lorenz_T_200.npz
# Analyzing VAR data with T=500
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 6 link(s):
#         (X0 -3): max_pval = 0.00042, |min_val| =  0.160
#         (X0 -2): max_pval = 0.00106, |min_val| =  0.148
#         (X7 -4): max_pval = 0.00982, |min_val| =  0.117
#         (X5 -4): max_pval = 0.03228, |min_val| =  0.097
#         (X0 -5): max_pval = 0.04722, |min_val| =  0.090
#         (X0 -1): max_pval = 0.04897, |min_val| =  0.090
#
#     Variable X1 has 6 link(s):
#         (X1 -1): max_pval = 0.00003, |min_val| =  0.189
#         (X3 -4): max_pval = 0.00047, |min_val| =  0.158
#         (X3 -2): max_pval = 0.00155, |min_val| =  0.143
#         (X3 -3): max_pval = 0.01011, |min_val| =  0.117
#         (X1 -4): max_pval = 0.01055, |min_val| =  0.116
#         (X1 -5): max_pval = 0.01285, |min_val| =  0.113
#
#     Variable X2 has 7 link(s):
#         (X2 -2): max_pval = 0.00324, |min_val| =  0.133
#         (X1 -3): max_pval = 0.01089, |min_val| =  0.116
#         (X2 -1): max_pval = 0.01192, |min_val| =  0.114
#         (X4 -5): max_pval = 0.01679, |min_val| =  0.109
#         (X9 -5): max_pval = 0.03943, |min_val| =  0.094
#         (X2 -3): max_pval = 0.03962, |min_val| =  0.094
#         (X4 -3): max_pval = 0.04085, |min_val| =  0.093
#
#     Variable X3 has 7 link(s):
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.207
#         (X6 -2): max_pval = 0.00085, |min_val| =  0.151
#         (X3 -4): max_pval = 0.00173, |min_val| =  0.142
#         (X3 -2): max_pval = 0.00259, |min_val| =  0.137
#         (X3 -3): max_pval = 0.00552, |min_val| =  0.126
#         (X6 -3): max_pval = 0.01534, |min_val| =  0.110
#         (X9 -5): max_pval = 0.02799, |min_val| =  0.100
#
#     Variable X4 has 7 link(s):
#         (X4 -1): max_pval = 0.00052, |min_val| =  0.157
#         (X9 -5): max_pval = 0.00063, |min_val| =  0.155
#         (X9 -2): max_pval = 0.00610, |min_val| =  0.124
#         (X4 -5): max_pval = 0.00775, |min_val| =  0.121
#         (X4 -2): max_pval = 0.00784, |min_val| =  0.121
#         (X9 -1): max_pval = 0.01159, |min_val| =  0.115
#         (X9 -3): max_pval = 0.01772, |min_val| =  0.108
#
#     Variable X5 has 5 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.225
#         (X5 -2): max_pval = 0.00003, |min_val| =  0.188
#         (X5 -3): max_pval = 0.00099, |min_val| =  0.149
#         (X4 -3): max_pval = 0.00269, |min_val| =  0.136
#         (X5 -4): max_pval = 0.00418, |min_val| =  0.130
#
#     Variable X6 has 6 link(s):
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.215
#         (X5 -1): max_pval = 0.00005, |min_val| =  0.182
#         (X6 -3): max_pval = 0.00049, |min_val| =  0.158
#         (X5 -3): max_pval = 0.00325, |min_val| =  0.133
#         (X6 -4): max_pval = 0.01235, |min_val| =  0.114
#         (X6 -2): max_pval = 0.01303, |min_val| =  0.113
#
#     Variable X7 has 8 link(s):
#         (X7 -5): max_pval = 0.00001, |min_val| =  0.195
#         (X7 -3): max_pval = 0.00048, |min_val| =  0.158
#         (X3 -2): max_pval = 0.00115, |min_val| =  0.148
#         (X7 -1): max_pval = 0.00164, |min_val| =  0.143
#         (X1 -4): max_pval = 0.00686, |min_val| =  0.123
#         (X1 -1): max_pval = 0.01488, |min_val| =  0.111
#         (X1 -2): max_pval = 0.01531, |min_val| =  0.110
#         (X1 -5): max_pval = 0.01541, |min_val| =  0.110
#
#     Variable X8 has 5 link(s):
#         (X5 -1): max_pval = 0.00005, |min_val| =  0.183
#         (X5 -5): max_pval = 0.00053, |min_val| =  0.157
#         (X8 -1): max_pval = 0.00130, |min_val| =  0.145
#         (X8 -3): max_pval = 0.01274, |min_val| =  0.113
#         (X3 -3): max_pval = 0.01999, |min_val| =  0.106
#
#     Variable X9 has 6 link(s):
#         (X9 -4): max_pval = 0.00021, |min_val| =  0.168
#         (X9 -1): max_pval = 0.00094, |min_val| =  0.150
#         (X9 -2): max_pval = 0.00809, |min_val| =  0.120
#         (X5 -5): max_pval = 0.00903, |min_val| =  0.119
#         (X9 -5): max_pval = 0.01906, |min_val| =  0.107
#         (X3 -4): max_pval = 0.02544, |min_val| =  0.102
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 3 link(s):
#         (X0 -3): pval = 0.00166 | val =  0.143
#         (X5 -4): pval = 0.00769 | val =  0.122
#         (X0 -2): pval = 0.01347 | val =  0.113
#
#     Variable X1 has 10 link(s):
#         (X0 -3): pval = 0.00012 | val = -0.175
#         (X1 -1): pval = 0.00012 | val =  0.174
#         (X3 -2): pval = 0.00042 | val =  0.161
#         (X3 -4): pval = 0.00052 | val =  0.158
#         (X3 -3): pval = 0.00652 | val =  0.124
#         (X1 -5): pval = 0.00824 | val =  0.121
#         (X1 -4): pval = 0.00950 | val =  0.118
#         (X4 -4): pval = 0.02237 | val = -0.105
#         (X5  0): pval = 0.03463 | val =  0.097 | unoriented link
#         (X6 -5): pval = 0.04257 | val = -0.093
#
#     Variable X2 has 4 link(s):
#         (X1 -3): pval = 0.01424 | val =  0.112
#         (X5 -4): pval = 0.01642 | val = -0.110
#         (X2 -2): pval = 0.02770 | val =  0.101
#         (X2 -1): pval = 0.04243 | val =  0.093
#
#     Variable X3 has 7 link(s):
#         (X5 -2): pval = 0.00049 | val =  0.159
#         (X3 -2): pval = 0.00658 | val =  0.124
#         (X3 -4): pval = 0.00673 | val =  0.124
#         (X6 -2): pval = 0.00703 | val =  0.123
#         (X1 -5): pval = 0.01373 | val = -0.113
#         (X3 -3): pval = 0.02540 | val =  0.102
#         (X9 -5): pval = 0.04385 | val =  0.092
#
#     Variable X4 has 7 link(s):
#         (X4 -1): pval = 0.00096 | val =  0.150
#         (X9 -5): pval = 0.00157 | val =  0.144
#         (X4 -5): pval = 0.00502 | val =  0.128
#         (X9 -2): pval = 0.00709 | val =  0.123
#         (X9 -1): pval = 0.01131 | val =  0.115
#         (X9 -3): pval = 0.01750 | val =  0.109
#         (X4 -2): pval = 0.02105 | val =  0.105
#
#     Variable X5 has 12 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.219
#         (X6 -1): pval = 0.00018 | val = -0.170
#         (X5 -2): pval = 0.00021 | val =  0.168
#         (X4 -3): pval = 0.00846 | val =  0.120
#         (X8 -1): pval = 0.00923 | val = -0.119
#         (X0 -5): pval = 0.02100 | val = -0.105
#         (X9 -3): pval = 0.02589 | val =  0.102
#         (X5 -4): pval = 0.02743 | val =  0.101
#         (X5 -3): pval = 0.03365 | val =  0.097
#         (X1  0): pval = 0.03463 | val =  0.097 | unoriented link
#         (X6 -5): pval = 0.04362 | val = -0.092
#         (X1 -4): pval = 0.04579 | val = -0.091
#
#     Variable X6 has 6 link(s):
#         (X5 -2): pval = 0.00003 | val =  0.189
#         (X5 -1): pval = 0.00034 | val =  0.163
#         (X5 -3): pval = 0.00571 | val =  0.126
#         (X6 -3): pval = 0.01126 | val =  0.116
#         (X6 -4): pval = 0.03809 | val =  0.095
#         (X5 -4): pval = 0.04425 | val =  0.092
#
#     Variable X7 has 11 link(s):
#         (X7 -5): pval = 0.00002 | val =  0.197
#         (X7 -3): pval = 0.00048 | val =  0.159
#         (X3 -2): pval = 0.00093 | val =  0.151
#         (X7 -1): pval = 0.00214 | val =  0.140
#         (X1 -1): pval = 0.00380 | val =  0.132
#         (X1 -4): pval = 0.00522 | val =  0.128
#         (X1 -5): pval = 0.00878 | val =  0.120
#         (X8 -3): pval = 0.00975 | val = -0.118
#         (X4 -5): pval = 0.01018 | val = -0.118
#         (X3 -3): pval = 0.01199 | val = -0.115
#         (X1 -2): pval = 0.01505 | val =  0.111
#
#     Variable X8 has 7 link(s):
#         (X5 -1): pval = 0.00066 | val =  0.155
#         (X5 -5): pval = 0.00158 | val =  0.144
#         (X1 -3): pval = 0.00702 | val = -0.123
#         (X3 -3): pval = 0.00950 | val =  0.118
#         (X8 -1): pval = 0.02944 | val =  0.099
#         (X8 -3): pval = 0.03232 | val =  0.098
#         (X8 -2): pval = 0.04319 | val =  0.092
#
#     Variable X9 has 8 link(s):
#         (X9 -4): pval = 0.00015 | val =  0.173
#         (X9 -1): pval = 0.00261 | val =  0.137
#         (X5 -5): pval = 0.00414 | val =  0.131
#         (X9 -2): pval = 0.02131 | val =  0.105
#         (X2 -2): pval = 0.02348 | val = -0.104
#         (X1 -4): pval = 0.04048 | val = -0.094
#         (X9 -5): pval = 0.04777 | val =  0.090
#         (X3 -4): pval = 0.04988 | val =  0.090
# AUROC for VAR with T=500: 0.43125
# Analyzing Lorenz-96 data with T=500
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 9 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.851
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.588
#         (X0 -3): max_pval = 0.00000, |min_val| =  0.376
#         (X0 -4): max_pval = 0.00001, |min_val| =  0.204
#         (X1 -1): max_pval = 0.00035, |min_val| =  0.162
#         (X9 -1): max_pval = 0.00135, |min_val| =  0.145
#         (X8 -1): max_pval = 0.00435, |min_val| =  0.129
#         (X7 -2): max_pval = 0.04437, |min_val| =  0.091
#         (X9 -2): max_pval = 0.04745, |min_val| =  0.090
#
#     Variable X1 has 5 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.808
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.419
#         (X2 -1): max_pval = 0.00009, |min_val| =  0.176
#         (X1 -3): max_pval = 0.01908, |min_val| =  0.106
#         (X1 -5): max_pval = 0.03806, |min_val| =  0.094
#
#     Variable X2 has 6 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.854
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.546
#         (X2 -3): max_pval = 0.00000, |min_val| =  0.270
#         (X3 -1): max_pval = 0.00020, |min_val| =  0.167
#         (X0 -1): max_pval = 0.00178, |min_val| =  0.141
#         (X2 -4): max_pval = 0.02447, |min_val| =  0.102
#
#     Variable X3 has 6 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.848
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.530
#         (X3 -3): max_pval = 0.00000, |min_val| =  0.253
#         (X0 -5): max_pval = 0.00002, |min_val| =  0.193
#         (X4 -1): max_pval = 0.00029, |min_val| =  0.164
#         (X3 -4): max_pval = 0.03741, |min_val| =  0.094
#
#     Variable X4 has 6 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.825
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.462
#         (X5 -1): max_pval = 0.00002, |min_val| =  0.194
#         (X4 -3): max_pval = 0.00073, |min_val| =  0.152
#         (X1 -4): max_pval = 0.00793, |min_val| =  0.120
#         (X5 -3): max_pval = 0.02680, |min_val| =  0.100
#
#     Variable X5 has 6 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.815
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.455
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.217
#         (X5 -3): max_pval = 0.00003, |min_val| =  0.187
#         (X3 -1): max_pval = 0.02156, |min_val| =  0.104
#         (X0 -2): max_pval = 0.02354, |min_val| =  0.103
#
#     Variable X6 has 7 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.835
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.489
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.229
#         (X6 -3): max_pval = 0.00003, |min_val| =  0.186
#         (X0 -2): max_pval = 0.00924, |min_val| =  0.118
#         (X1 -4): max_pval = 0.01975, |min_val| =  0.106
#         (X4 -1): max_pval = 0.02181, |min_val| =  0.104
#
#     Variable X7 has 6 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.835
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.501
#         (X7 -3): max_pval = 0.00000, |min_val| =  0.212
#         (X8 -1): max_pval = 0.00006, |min_val| =  0.181
#         (X4 -5): max_pval = 0.01689, |min_val| =  0.108
#         (X4 -4): max_pval = 0.01831, |min_val| =  0.107
#
#     Variable X8 has 5 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.806
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.439
#         (X8 -3): max_pval = 0.00047, |min_val| =  0.158
#         (X9 -1): max_pval = 0.00564, |min_val| =  0.125
#         (X5 -5): max_pval = 0.01578, |min_val| =  0.110
#
#     Variable X9 has 7 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.854
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.575
#         (X9 -3): max_pval = 0.00000, |min_val| =  0.316
#         (X6 -5): max_pval = 0.00013, |min_val| =  0.173
#         (X9 -4): max_pval = 0.00314, |min_val| =  0.133
#         (X0 -1): max_pval = 0.01296, |min_val| =  0.112
#         (X7 -1): max_pval = 0.02571, |min_val| =  0.101
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 18 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.853
#         (X0 -2): pval = 0.00000 | val = -0.536
#         (X1 -1): pval = 0.00000 | val =  0.402
#         (X0 -3): pval = 0.00000 | val =  0.322
#         (X1 -2): pval = 0.00000 | val = -0.297
#         (X9 -1): pval = 0.00000 | val = -0.226
#         (X1 -3): pval = 0.00000 | val = -0.209
#         (X3 -3): pval = 0.00004 | val =  0.188
#         (X8  0): pval = 0.00041 | val = -0.161 | unoriented link
#         (X2 -2): pval = 0.00051 | val =  0.159
#         (X0 -4): pval = 0.00121 | val = -0.148
#         (X2  0): pval = 0.00218 | val = -0.140 | unoriented link
#         (X9 -2): pval = 0.00228 | val =  0.140
#         (X9 -4): pval = 0.00352 | val = -0.134
#         (X8 -1): pval = 0.00499 | val = -0.128
#         (X7  0): pval = 0.00537 | val =  0.127 | unoriented link
#         (X3 -2): pval = 0.00725 | val = -0.123
#         (X2 -4): pval = 0.02040 | val = -0.106
#
#     Variable X1 has 17 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.881
#         (X1 -2): pval = 0.00000 | val = -0.651
#         (X1 -3): pval = 0.00000 | val =  0.457
#         (X2 -1): pval = 0.00000 | val =  0.343
#         (X1 -4): pval = 0.00000 | val = -0.296
#         (X2 -2): pval = 0.00000 | val = -0.259
#         (X0 -1): pval = 0.00000 | val = -0.245
#         (X2 -3): pval = 0.00001 | val = -0.197
#         (X3 -1): pval = 0.00002 | val = -0.195
#         (X3  0): pval = 0.00002 | val = -0.194 | unoriented link
#         (X1 -5): pval = 0.00017 | val = -0.171
#         (X2  0): pval = 0.00073 | val = -0.154 | unoriented link
#         (X3 -2): pval = 0.00570 | val =  0.126
#         (X9 -1): pval = 0.01554 | val = -0.111
#         (X4  0): pval = 0.01573 | val =  0.110 | unoriented link
#         (X2 -5): pval = 0.01757 | val = -0.108
#         (X0 -2): pval = 0.03188 | val =  0.098
#
#     Variable X2 has 26 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.883
#         (X2 -2): pval = 0.00000 | val = -0.648
#         (X2 -3): pval = 0.00000 | val =  0.459
#         (X3 -1): pval = 0.00000 | val =  0.424
#         (X3 -2): pval = 0.00000 | val = -0.333
#         (X2 -4): pval = 0.00000 | val = -0.327
#         (X2 -5): pval = 0.00000 | val =  0.239
#         (X4 -2): pval = 0.00000 | val =  0.214
#         (X1 -1): pval = 0.00001 | val = -0.199
#         (X9 -4): pval = 0.00005 | val =  0.185
#         (X3 -3): pval = 0.00009 | val = -0.179
#         (X3 -5): pval = 0.00025 | val = -0.167
#         (X4  0): pval = 0.00041 | val = -0.161 | unoriented link
#         (X4 -1): pval = 0.00071 | val = -0.154
#         (X1  0): pval = 0.00073 | val = -0.154 | unoriented link
#         (X0  0): pval = 0.00218 | val = -0.140 | unoriented link
#         (X5 -3): pval = 0.00255 | val =  0.138
#         (X8 -4): pval = 0.00461 | val = -0.129
#         (X6 -2): pval = 0.00662 | val = -0.124
#         (X9 -3): pval = 0.00727 | val =  0.123
#         (X5  0): pval = 0.00926 | val =  0.119 | unoriented link
#         (X4 -3): pval = 0.02120 | val =  0.105
#         (X1 -2): pval = 0.02264 | val =  0.104
#         (X6 -4): pval = 0.02940 | val =  0.100
#         (X7 -5): pval = 0.02990 | val =  0.099
#         (X3  0): pval = 0.03106 | val = -0.099 | unoriented link
#
#     Variable X3 has 26 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.888
#         (X3 -2): pval = 0.00000 | val = -0.656
#         (X3 -3): pval = 0.00000 | val =  0.431
#         (X4 -1): pval = 0.00000 | val =  0.284
#         (X3 -4): pval = 0.00000 | val = -0.234
#         (X2 -1): pval = 0.00000 | val = -0.233
#         (X5 -2): pval = 0.00001 | val =  0.204
#         (X1  0): pval = 0.00002 | val = -0.194 | unoriented link
#         (X4 -2): pval = 0.00004 | val = -0.187
#         (X4 -3): pval = 0.00013 | val = -0.174
#         (X5 -1): pval = 0.00055 | val = -0.157
#         (X6 -3): pval = 0.00069 | val =  0.155
#         (X0 -4): pval = 0.00081 | val =  0.153
#         (X5  0): pval = 0.00181 | val = -0.142 | unoriented link
#         (X9 -4): pval = 0.00266 | val = -0.137
#         (X2 -2): pval = 0.00377 | val =  0.132
#         (X7 -4): pval = 0.01188 | val =  0.115
#         (X3 -5): pval = 0.01309 | val =  0.113
#         (X8 -5): pval = 0.01834 | val =  0.108
#         (X9 -1): pval = 0.02459 | val = -0.103
#         (X8 -3): pval = 0.02574 | val = -0.102
#         (X2  0): pval = 0.03106 | val = -0.099 | unoriented link
#         (X1 -1): pval = 0.03860 | val = -0.095
#         (X7  0): pval = 0.04661 | val =  0.091 | unoriented link
#         (X8 -4): pval = 0.04648 | val =  0.091
#         (X4  0): pval = 0.04870 | val = -0.090 | unoriented link
#
#     Variable X4 has 25 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.886
#         (X4 -2): pval = 0.00000 | val = -0.644
#         (X4 -3): pval = 0.00000 | val =  0.442
#         (X5 -1): pval = 0.00000 | val =  0.375
#         (X5 -3): pval = 0.00000 | val = -0.301
#         (X4 -4): pval = 0.00000 | val = -0.282
#         (X5 -4): pval = 0.00000 | val =  0.233
#         (X4 -5): pval = 0.00000 | val = -0.232
#         (X5 -2): pval = 0.00002 | val = -0.195
#         (X6 -2): pval = 0.00018 | val =  0.170
#         (X3 -1): pval = 0.00023 | val = -0.168
#         (X2  0): pval = 0.00041 | val = -0.161 | unoriented link
#         (X5 -5): pval = 0.00145 | val =  0.145
#         (X2 -3): pval = 0.00172 | val = -0.143
#         (X2 -2): pval = 0.00193 | val = -0.141
#         (X8 -2): pval = 0.00327 | val = -0.134
#         (X7 -3): pval = 0.00338 | val =  0.134
#         (X5  0): pval = 0.00655 | val = -0.124 | unoriented link
#         (X6  0): pval = 0.00933 | val = -0.119 | unoriented link
#         (X8 -5): pval = 0.01451 | val = -0.112
#         (X1  0): pval = 0.01573 | val =  0.110 | unoriented link
#         (X9 -3): pval = 0.02182 | val = -0.105
#         (X1 -4): pval = 0.02191 | val =  0.105
#         (X7 -1): pval = 0.02318 | val = -0.104
#         (X3  0): pval = 0.04870 | val = -0.090 | unoriented link
#
#     Variable X5 has 15 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.866
#         (X5 -2): pval = 0.00000 | val = -0.607
#         (X5 -3): pval = 0.00000 | val =  0.413
#         (X6 -1): pval = 0.00000 | val =  0.280
#         (X5 -4): pval = 0.00000 | val = -0.223
#         (X7  0): pval = 0.00000 | val = -0.213 | unoriented link
#         (X6 -3): pval = 0.00002 | val = -0.194
#         (X6 -2): pval = 0.00035 | val = -0.163
#         (X7 -2): pval = 0.00076 | val =  0.153
#         (X4 -1): pval = 0.00098 | val = -0.150
#         (X3  0): pval = 0.00181 | val = -0.142 | unoriented link
#         (X8 -3): pval = 0.00392 | val =  0.132
#         (X4  0): pval = 0.00655 | val = -0.124 | unoriented link
#         (X2  0): pval = 0.00926 | val =  0.119 | unoriented link
#         (X6  0): pval = 0.01796 | val = -0.108 | unoriented link
#
#     Variable X6 has 18 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.877
#         (X6 -2): pval = 0.00000 | val = -0.626
#         (X6 -3): pval = 0.00000 | val =  0.420
#         (X7 -1): pval = 0.00000 | val =  0.398
#         (X7 -2): pval = 0.00000 | val = -0.311
#         (X6 -4): pval = 0.00000 | val = -0.220
#         (X5 -1): pval = 0.00000 | val = -0.207
#         (X7 -3): pval = 0.00011 | val = -0.176
#         (X6 -5): pval = 0.00018 | val = -0.171
#         (X8 -2): pval = 0.00033 | val =  0.164
#         (X9 -1): pval = 0.00067 | val = -0.155
#         (X0 -2): pval = 0.00283 | val = -0.137
#         (X8  0): pval = 0.00748 | val = -0.122 | unoriented link
#         (X4  0): pval = 0.00933 | val = -0.119 | unoriented link
#         (X0 -4): pval = 0.01819 | val =  0.108
#         (X5  0): pval = 0.01796 | val = -0.108 | unoriented link
#         (X9 -3): pval = 0.02433 | val =  0.103
#         (X2 -1): pval = 0.03733 | val = -0.095
#
#     Variable X7 has 21 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.866
#         (X7 -2): pval = 0.00000 | val = -0.586
#         (X7 -3): pval = 0.00000 | val =  0.388
#         (X8 -1): pval = 0.00000 | val =  0.333
#         (X7 -4): pval = 0.00000 | val = -0.247
#         (X6 -1): pval = 0.00000 | val = -0.243
#         (X5  0): pval = 0.00000 | val = -0.213 | unoriented link
#         (X8 -2): pval = 0.00001 | val = -0.203
#         (X9 -2): pval = 0.00007 | val =  0.180
#         (X9 -4): pval = 0.00014 | val = -0.174
#         (X5 -3): pval = 0.00227 | val = -0.139
#         (X8 -3): pval = 0.00244 | val = -0.138
#         (X0  0): pval = 0.00537 | val =  0.127 | unoriented link
#         (X0 -5): pval = 0.00677 | val = -0.124
#         (X5 -2): pval = 0.01571 | val = -0.110
#         (X9 -1): pval = 0.01600 | val = -0.110
#         (X5 -1): pval = 0.02079 | val = -0.106
#         (X9  0): pval = 0.02944 | val = -0.100 | unoriented link
#         (X6 -2): pval = 0.03849 | val =  0.095
#         (X0 -3): pval = 0.04244 | val =  0.093
#         (X3  0): pval = 0.04661 | val =  0.091 | unoriented link
#
#     Variable X8 has 12 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.876
#         (X8 -2): pval = 0.00000 | val = -0.667
#         (X8 -3): pval = 0.00000 | val =  0.494
#         (X8 -4): pval = 0.00000 | val = -0.333
#         (X8 -5): pval = 0.00000 | val = -0.220
#         (X7 -1): pval = 0.00006 | val = -0.182
#         (X9 -3): pval = 0.00010 | val = -0.178
#         (X0  0): pval = 0.00041 | val = -0.161 | unoriented link
#         (X9 -1): pval = 0.00116 | val =  0.148
#         (X9  0): pval = 0.00457 | val = -0.129 | unoriented link
#         (X0 -4): pval = 0.00536 | val = -0.127
#         (X6  0): pval = 0.00748 | val = -0.122 | unoriented link
#
#     Variable X9 has 12 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.861
#         (X9 -2): pval = 0.00000 | val = -0.592
#         (X9 -3): pval = 0.00000 | val =  0.387
#         (X9 -4): pval = 0.00000 | val = -0.234
#         (X0 -1): pval = 0.00001 | val =  0.199
#         (X0 -2): pval = 0.00271 | val = -0.137
#         (X8  0): pval = 0.00457 | val = -0.129 | unoriented link
#         (X9 -5): pval = 0.01676 | val =  0.110
#         (X0 -3): pval = 0.01828 | val = -0.108
#         (X7  0): pval = 0.02944 | val = -0.100 | unoriented link
#         (X8 -1): pval = 0.03917 | val = -0.094
#         (X1 -2): pval = 0.04353 | val =  0.092
# AUROC for Lorenz-96 with T=500: 0.16666666666666663
# Saved VAR results to results_var_T_500.npz
# Saved Lorenz-96 results to results_lorenz_T_500.npz
# Analyzing VAR data with T=1000
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 10 link(s):
#         (X0 -1): max_pval = 0.00023, |min_val| =  0.117
#         (X5 -3): max_pval = 0.00035, |min_val| =  0.114
#         (X0 -3): max_pval = 0.00079, |min_val| =  0.107
#         (X5 -1): max_pval = 0.00209, |min_val| =  0.098
#         (X0 -5): max_pval = 0.00214, |min_val| =  0.098
#         (X5 -5): max_pval = 0.00363, |min_val| =  0.093
#         (X0 -2): max_pval = 0.00464, |min_val| =  0.090
#         (X0 -4): max_pval = 0.00553, |min_val| =  0.089
#         (X5 -2): max_pval = 0.00650, |min_val| =  0.087
#         (X3 -3): max_pval = 0.02527, |min_val| =  0.071
#
#     Variable X1 has 9 link(s):
#         (X1 -2): max_pval = 0.00002, |min_val| =  0.134
#         (X1 -1): max_pval = 0.00026, |min_val| =  0.116
#         (X3 -4): max_pval = 0.00073, |min_val| =  0.108
#         (X3 -1): max_pval = 0.00097, |min_val| =  0.105
#         (X3 -3): max_pval = 0.00255, |min_val| =  0.096
#         (X1 -3): max_pval = 0.00822, |min_val| =  0.084
#         (X3 -5): max_pval = 0.01738, |min_val| =  0.076
#         (X8 -5): max_pval = 0.02556, |min_val| =  0.071
#         (X1 -4): max_pval = 0.03889, |min_val| =  0.066
#
#     Variable X2 has 10 link(s):
#         (X9 -3): max_pval = 0.00001, |min_val| =  0.140
#         (X9 -4): max_pval = 0.00014, |min_val| =  0.121
#         (X2 -1): max_pval = 0.00151, |min_val| =  0.101
#         (X2 -2): max_pval = 0.00174, |min_val| =  0.100
#         (X9 -2): max_pval = 0.00958, |min_val| =  0.083
#         (X2 -5): max_pval = 0.01063, |min_val| =  0.081
#         (X2 -3): max_pval = 0.01085, |min_val| =  0.081
#         (X9 -5): max_pval = 0.02011, |min_val| =  0.074
#         (X2 -4): max_pval = 0.02718, |min_val| =  0.071
#         (X9 -1): max_pval = 0.04156, |min_val| =  0.065
#
#     Variable X3 has 11 link(s):
#         (X5 -2): max_pval = 0.00001, |min_val| =  0.144
#         (X5 -3): max_pval = 0.00002, |min_val| =  0.137
#         (X3 -3): max_pval = 0.00004, |min_val| =  0.130
#         (X3 -5): max_pval = 0.00086, |min_val| =  0.106
#         (X5 -1): max_pval = 0.00472, |min_val| =  0.090
#         (X5 -4): max_pval = 0.00581, |min_val| =  0.088
#         (X5 -5): max_pval = 0.00598, |min_val| =  0.088
#         (X7 -2): max_pval = 0.01983, |min_val| =  0.074
#         (X3 -2): max_pval = 0.02208, |min_val| =  0.073
#         (X0 -1): max_pval = 0.02464, |min_val| =  0.072
#         (X3 -4): max_pval = 0.04442, |min_val| =  0.064
#
#     Variable X4 has 10 link(s):
#         (X9 -1): max_pval = 0.00028, |min_val| =  0.116
#         (X4 -3): max_pval = 0.00060, |min_val| =  0.109
#         (X4 -1): max_pval = 0.00102, |min_val| =  0.105
#         (X6 -5): max_pval = 0.00670, |min_val| =  0.087
#         (X4 -4): max_pval = 0.00876, |min_val| =  0.084
#         (X4 -5): max_pval = 0.01437, |min_val| =  0.078
#         (X9 -3): max_pval = 0.01524, |min_val| =  0.078
#         (X9 -5): max_pval = 0.01585, |min_val| =  0.077
#         (X9 -2): max_pval = 0.01809, |min_val| =  0.075
#         (X4 -2): max_pval = 0.03983, |min_val| =  0.066
#
#     Variable X5 has 8 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.152
#         (X5 -3): max_pval = 0.00003, |min_val| =  0.132
#         (X4 -5): max_pval = 0.00007, |min_val| =  0.126
#         (X4 -1): max_pval = 0.00011, |min_val| =  0.123
#         (X4 -2): max_pval = 0.00012, |min_val| =  0.122
#         (X5 -4): max_pval = 0.00294, |min_val| =  0.095
#         (X4 -3): max_pval = 0.00338, |min_val| =  0.093
#         (X8 -1): max_pval = 0.04984, |min_val| =  0.063
#
#     Variable X6 has 8 link(s):
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.190
#         (X5 -4): max_pval = 0.00000, |min_val| =  0.180
#         (X6 -3): max_pval = 0.00000, |min_val| =  0.180
#         (X6 -4): max_pval = 0.00006, |min_val| =  0.128
#         (X6 -2): max_pval = 0.00077, |min_val| =  0.107
#         (X5 -5): max_pval = 0.00533, |min_val| =  0.089
#         (X5 -3): max_pval = 0.04624, |min_val| =  0.064
#         (X2 -2): max_pval = 0.04820, |min_val| =  0.063
#
#     Variable X7 has 7 link(s):
#         (X1 -5): max_pval = 0.00000, |min_val| =  0.166
#         (X7 -1): max_pval = 0.00014, |min_val| =  0.121
#         (X7 -2): max_pval = 0.00031, |min_val| =  0.115
#         (X1 -1): max_pval = 0.00046, |min_val| =  0.111
#         (X1 -3): max_pval = 0.00227, |min_val| =  0.097
#         (X7 -3): max_pval = 0.00954, |min_val| =  0.083
#         (X1 -2): max_pval = 0.01949, |min_val| =  0.074
#
#     Variable X8 has 10 link(s):
#         (X5 -5): max_pval = 0.00001, |min_val| =  0.145
#         (X8 -5): max_pval = 0.00006, |min_val| =  0.128
#         (X0 -1): max_pval = 0.00207, |min_val| =  0.098
#         (X5 -3): max_pval = 0.00943, |min_val| =  0.083
#         (X8 -2): max_pval = 0.01122, |min_val| =  0.081
#         (X8 -1): max_pval = 0.01454, |min_val| =  0.078
#         (X5 -2): max_pval = 0.01595, |min_val| =  0.077
#         (X8 -4): max_pval = 0.04119, |min_val| =  0.065
#         (X5 -4): max_pval = 0.04210, |min_val| =  0.065
#         (X5 -1): max_pval = 0.04955, |min_val| =  0.063
#
#     Variable X9 has 6 link(s):
#         (X9 -5): max_pval = 0.00000, |min_val| =  0.179
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.170
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.159
#         (X3 -1): max_pval = 0.00023, |min_val| =  0.117
#         (X3 -4): max_pval = 0.00121, |min_val| =  0.103
#         (X3 -5): max_pval = 0.00139, |min_val| =  0.102
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 12 link(s):
#         (X5 -3): pval = 0.00011 | val =  0.123
#         (X0 -1): pval = 0.00027 | val =  0.116
#         (X5 -5): pval = 0.00130 | val =  0.103
#         (X0 -3): pval = 0.00177 | val =  0.100
#         (X5 -2): pval = 0.00183 | val =  0.100
#         (X5 -1): pval = 0.00307 | val =  0.095
#         (X0 -5): pval = 0.00337 | val =  0.094
#         (X0 -2): pval = 0.00425 | val =  0.091
#         (X2  0): pval = 0.00604 | val = -0.088 | unoriented link
#         (X0 -4): pval = 0.00617 | val =  0.088
#         (X3 -3): pval = 0.02413 | val =  0.072
#         (X4 -2): pval = 0.02956 | val =  0.070
#
#     Variable X1 has 8 link(s):
#         (X1 -2): pval = 0.00014 | val =  0.122
#         (X1 -1): pval = 0.00046 | val =  0.112
#         (X7 -4): pval = 0.00052 | val = -0.111
#         (X3 -1): pval = 0.00110 | val =  0.104
#         (X3 -4): pval = 0.00157 | val =  0.101
#         (X3 -3): pval = 0.00193 | val =  0.099
#         (X1 -3): pval = 0.02708 | val =  0.071
#         (X3 -5): pval = 0.04793 | val =  0.063
#
#     Variable X2 has 11 link(s):
#         (X9 -3): pval = 0.00001 | val =  0.138
#         (X9 -4): pval = 0.00014 | val =  0.121
#         (X2 -2): pval = 0.00157 | val =  0.101
#         (X2 -1): pval = 0.00176 | val =  0.100
#         (X0  0): pval = 0.00604 | val = -0.088 | unoriented link
#         (X9 -2): pval = 0.00620 | val =  0.088
#         (X2 -5): pval = 0.01236 | val =  0.080
#         (X6 -3): pval = 0.01365 | val =  0.079
#         (X2 -3): pval = 0.01464 | val =  0.078
#         (X9 -5): pval = 0.02155 | val =  0.074
#         (X2 -4): pval = 0.02689 | val =  0.071
#
#     Variable X3 has 12 link(s):
#         (X5 -3): pval = 0.00002 | val =  0.135
#         (X5 -2): pval = 0.00002 | val =  0.135
#         (X3 -3): pval = 0.00015 | val =  0.122
#         (X3 -5): pval = 0.00074 | val =  0.108
#         (X5 -1): pval = 0.00151 | val =  0.101
#         (X9 -3): pval = 0.00429 | val = -0.091
#         (X5 -4): pval = 0.00912 | val =  0.084
#         (X5 -5): pval = 0.01097 | val =  0.082
#         (X1 -2): pval = 0.02485 | val = -0.072
#         (X3 -2): pval = 0.03238 | val =  0.069
#         (X3 -4): pval = 0.04255 | val =  0.065
#         (X7 -2): pval = 0.04731 | val =  0.064
#
#     Variable X4 has 12 link(s):
#         (X4 -3): pval = 0.00030 | val =  0.116
#         (X9 -1): pval = 0.00073 | val =  0.108
#         (X4 -1): pval = 0.00110 | val =  0.104
#         (X4 -4): pval = 0.00156 | val =  0.101
#         (X4 -5): pval = 0.00679 | val =  0.087
#         (X9 -5): pval = 0.00880 | val =  0.084
#         (X9 -2): pval = 0.01171 | val =  0.081
#         (X2 -3): pval = 0.01201 | val = -0.081
#         (X4 -2): pval = 0.01462 | val =  0.078
#         (X9 -4): pval = 0.03329 | val =  0.068
#         (X6 -5): pval = 0.04390 | val =  0.065
#         (X9 -3): pval = 0.04595 | val =  0.064
#
#     Variable X5 has 7 link(s):
#         (X4 -5): pval = 0.00004 | val =  0.132
#         (X5 -1): pval = 0.00004 | val =  0.132
#         (X5 -3): pval = 0.00016 | val =  0.120
#         (X4 -1): pval = 0.00034 | val =  0.114
#         (X4 -2): pval = 0.00076 | val =  0.108
#         (X4 -3): pval = 0.00394 | val =  0.092
#         (X5 -4): pval = 0.02084 | val =  0.074
#
#     Variable X6 has 7 link(s):
#         (X5 -4): pval = 0.00000 | val =  0.155
#         (X5 -2): pval = 0.00000 | val =  0.152
#         (X6 -3): pval = 0.00000 | val =  0.150
#         (X6 -4): pval = 0.00280 | val =  0.096
#         (X6 -2): pval = 0.00888 | val =  0.084
#         (X5 -5): pval = 0.01475 | val =  0.078
#         (X0 -5): pval = 0.03554 | val =  0.067
#
#     Variable X7 has 10 link(s):
#         (X1 -5): pval = 0.00000 | val =  0.155
#         (X7 -1): pval = 0.00061 | val =  0.109
# ...
#         (X1 -3): max_pval = 0.00000, |min_val| =  0.183
#         (X0 -1): max_pval = 0.00252, |min_val| =  0.096
#         (X9 -2): max_pval = 0.02827, |min_val| =  0.070
#         (X7 -2): max_pval = 0.04648, |min_val| =  0.063
#
#     Variable X2 has 6 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.821
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.461
#         (X2 -3): max_pval = 0.00000, |min_val| =  0.170
#         (X3 -1): max_pval = 0.00003, |min_val| =  0.133
#         (X9 -5): max_pval = 0.00051, |min_val| =  0.110
#         (X4 -5): max_pval = 0.02165, |min_val| =  0.073
#
#     Variable X3 has 7 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.833
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.488
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.198
#         (X3 -3): max_pval = 0.00000, |min_val| =  0.183
#         (X3 -5): max_pval = 0.00524, |min_val| =  0.089
#         (X1 -1): max_pval = 0.00941, |min_val| =  0.083
#         (X0 -3): max_pval = 0.01741, |min_val| =  0.076
#
#     Variable X4 has 7 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.832
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.482
#         (X4 -3): max_pval = 0.00000, |min_val| =  0.186
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.175
#         (X2 -1): max_pval = 0.00307, |min_val| =  0.094
#         (X1 -5): max_pval = 0.01549, |min_val| =  0.077
#         (X4 -5): max_pval = 0.04035, |min_val| =  0.065
#
#     Variable X5 has 7 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.841
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.517
#         (X5 -3): max_pval = 0.00000, |min_val| =  0.237
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.211
#         (X2 -4): max_pval = 0.00052, |min_val| =  0.111
#         (X4 -1): max_pval = 0.02508, |min_val| =  0.071
#         (X3 -1): max_pval = 0.03314, |min_val| =  0.068
#
#     Variable X6 has 6 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.844
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.523
#         (X6 -3): max_pval = 0.00000, |min_val| =  0.252
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.197
#         (X6 -4): max_pval = 0.00343, |min_val| =  0.093
#         (X4 -1): max_pval = 0.00482, |min_val| =  0.090
#
#     Variable X7 has 7 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.830
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.476
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.176
#         (X7 -3): max_pval = 0.00000, |min_val| =  0.167
#         (X5 -1): max_pval = 0.00001, |min_val| =  0.140
#         (X6 -1): max_pval = 0.00552, |min_val| =  0.088
#         (X4 -5): max_pval = 0.01779, |min_val| =  0.076
#
#     Variable X8 has 5 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.837
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.505
#         (X8 -3): max_pval = 0.00000, |min_val| =  0.217
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.162
#         (X5 -5): max_pval = 0.00006, |min_val| =  0.127
#
#     Variable X9 has 8 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.844
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.522
#         (X9 -3): max_pval = 0.00000, |min_val| =  0.248
#         (X7 -1): max_pval = 0.00005, |min_val| =  0.129
#         (X0 -1): max_pval = 0.00049, |min_val| =  0.111
#         (X8 -1): max_pval = 0.00385, |min_val| =  0.092
#         (X9 -4): max_pval = 0.00753, |min_val| =  0.085
#         (X6 -5): max_pval = 0.02135, |min_val| =  0.073
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 25 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.882
#         (X0 -2): pval = 0.00000 | val = -0.648
#         (X0 -3): pval = 0.00000 | val =  0.479
#         (X1 -1): pval = 0.00000 | val =  0.346
#         (X0 -4): pval = 0.00000 | val = -0.304
#         (X9 -1): pval = 0.00000 | val = -0.277
#         (X0 -5): pval = 0.00000 | val = -0.195
#         (X1 -2): pval = 0.00000 | val = -0.193
#         (X8  0): pval = 0.00000 | val = -0.191 | unoriented link
#         (X1 -3): pval = 0.00000 | val = -0.167
#         (X2 -2): pval = 0.00169 | val =  0.100
#         (X9  0): pval = 0.00186 | val = -0.099 | unoriented link
#         (X6 -1): pval = 0.00233 | val = -0.097
#         (X3 -3): pval = 0.00287 | val =  0.095
#         (X1  0): pval = 0.00506 | val = -0.090 | unoriented link
#         (X7 -3): pval = 0.01088 | val =  0.081
#         (X7 -5): pval = 0.01094 | val =  0.081
#         (X4 -2): pval = 0.01143 | val = -0.081
#         (X8 -3): pval = 0.01540 | val = -0.077
#         (X7 -4): pval = 0.01744 | val =  0.076
#         (X5  0): pval = 0.01922 | val = -0.075 | unoriented link
#         (X2  0): pval = 0.02333 | val = -0.073 | unoriented link
#         (X6 -3): pval = 0.02409 | val =  0.072
#         (X3 -1): pval = 0.02961 | val = -0.070
#         (X9 -2): pval = 0.03806 | val =  0.066
#
#     Variable X1 has 22 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.869
#         (X1 -2): pval = 0.00000 | val = -0.614
#         (X1 -3): pval = 0.00000 | val =  0.395
#         (X2 -1): pval = 0.00000 | val =  0.346
#         (X2 -2): pval = 0.00000 | val = -0.222
#         (X2 -3): pval = 0.00000 | val = -0.211
#         (X1 -5): pval = 0.00000 | val = -0.195
#         (X0 -1): pval = 0.00000 | val = -0.195
#         (X3  0): pval = 0.00000 | val = -0.193 | unoriented link
#         (X1 -4): pval = 0.00000 | val = -0.192
#         (X3 -2): pval = 0.00000 | val =  0.168
#         (X0 -2): pval = 0.00000 | val =  0.167
#         (X9  0): pval = 0.00060 | val = -0.110 | unoriented link
#         (X2  0): pval = 0.00305 | val = -0.095 | unoriented link
#         (X4 -3): pval = 0.00388 | val =  0.092
#         (X8  0): pval = 0.00427 | val =  0.091 | unoriented link
#         (X0  0): pval = 0.00506 | val = -0.090 | unoriented link
#         (X4  0): pval = 0.01009 | val =  0.082 | unoriented link
#         (X4 -2): pval = 0.01226 | val = -0.080
#         (X8 -3): pval = 0.01598 | val =  0.077
#         (X3 -1): pval = 0.01994 | val = -0.074
#         (X3 -4): pval = 0.02757 | val = -0.071
#
#     Variable X2 has 25 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.872
#         (X2 -2): pval = 0.00000 | val = -0.626
#         (X2 -3): pval = 0.00000 | val =  0.431
#         (X3 -1): pval = 0.00000 | val =  0.325
#         (X3 -2): pval = 0.00000 | val = -0.239
#         (X2 -4): pval = 0.00000 | val = -0.239
#         (X1 -1): pval = 0.00000 | val = -0.200
#         (X4 -2): pval = 0.00000 | val =  0.200
#         (X3 -3): pval = 0.00000 | val = -0.195
#         (X4  0): pval = 0.00000 | val = -0.181 | unoriented link
#         (X2 -5): pval = 0.00004 | val = -0.131
#         (X4 -1): pval = 0.00027 | val = -0.116
#         (X5  0): pval = 0.00066 | val =  0.109 | unoriented link
#         (X3  0): pval = 0.00215 | val = -0.098 | unoriented link
#         (X6 -2): pval = 0.00303 | val = -0.095
#         (X1  0): pval = 0.00305 | val = -0.095 | unoriented link
#         (X0 -2): pval = 0.00965 | val = -0.083
#         (X5 -1): pval = 0.00974 | val = -0.083
#         (X8 -5): pval = 0.00968 | val =  0.083
#         (X5 -3): pval = 0.01361 | val =  0.079
#         (X9 -5): pval = 0.01831 | val =  0.075
#         (X0 -5): pval = 0.02306 | val = -0.073
#         (X0  0): pval = 0.02333 | val = -0.073 | unoriented link
#         (X4 -5): pval = 0.02478 | val =  0.072
#         (X7 -1): pval = 0.02527 | val =  0.072
#
#     Variable X3 has 25 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.868
#         (X3 -2): pval = 0.00000 | val = -0.626
#         (X3 -3): pval = 0.00000 | val =  0.424
#         (X4 -1): pval = 0.00000 | val =  0.324
#         (X3 -4): pval = 0.00000 | val = -0.285
#         (X4 -2): pval = 0.00000 | val = -0.254
#         (X1  0): pval = 0.00000 | val = -0.193 | unoriented link
#         (X2 -1): pval = 0.00000 | val = -0.162
#         (X4  0): pval = 0.00000 | val = -0.157 | unoriented link
#         (X5 -2): pval = 0.00000 | val =  0.151
#         (X5  0): pval = 0.00000 | val = -0.150 | unoriented link
#         (X4 -3): pval = 0.00001 | val = -0.142
#         (X3 -5): pval = 0.00001 | val = -0.141
#         (X5 -1): pval = 0.00052 | val = -0.111
#         (X2  0): pval = 0.00215 | val = -0.098 | unoriented link
#         (X7 -2): pval = 0.00335 | val = -0.094
#         (X8 -2): pval = 0.00546 | val = -0.089
#         (X9 -5): pval = 0.00835 | val =  0.084
#         (X6  0): pval = 0.01122 | val =  0.081 | unoriented link
#         (X4 -5): pval = 0.02199 | val = -0.073
#         (X1 -5): pval = 0.02531 | val = -0.072
#         (X8 -4): pval = 0.03083 | val =  0.069
#         (X0 -3): pval = 0.03098 | val =  0.069
#         (X7 -3): pval = 0.03544 | val =  0.067
#         (X8  0): pval = 0.04013 | val = -0.066 | unoriented link
#
#     Variable X4 has 24 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.879
#         (X4 -2): pval = 0.00000 | val = -0.649
#         (X4 -3): pval = 0.00000 | val =  0.453
#         (X5 -1): pval = 0.00000 | val =  0.301
#         (X4 -4): pval = 0.00000 | val = -0.300
#         (X5 -2): pval = 0.00000 | val = -0.225
#         (X3 -1): pval = 0.00000 | val = -0.207
#         (X2  0): pval = 0.00000 | val = -0.181 | unoriented link
#         (X3  0): pval = 0.00000 | val = -0.157 | unoriented link
#         (X4 -5): pval = 0.00005 | val = -0.129
#         (X6  0): pval = 0.00017 | val = -0.120 | unoriented link
#         (X5 -5): pval = 0.00041 | val = -0.113
#         (X2 -5): pval = 0.00127 | val = -0.103
#         (X1 -1): pval = 0.00296 | val = -0.095
#         (X8 -5): pval = 0.00459 | val = -0.091
#         (X1  0): pval = 0.01009 | val =  0.082 | unoriented link
#         (X5  0): pval = 0.01240 | val = -0.080 | unoriented link
#         (X3 -4): pval = 0.01584 | val =  0.077
#         (X2 -1): pval = 0.02148 | val = -0.074
#         (X3 -5): pval = 0.02613 | val =  0.071
#         (X7 -2): pval = 0.02742 | val =  0.071
#         (X9 -2): pval = 0.03179 | val = -0.069
#         (X6 -1): pval = 0.04180 | val = -0.065
#         (X7 -1): pval = 0.04961 | val = -0.063
#
#     Variable X5 has 25 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.872
#         (X5 -2): pval = 0.00000 | val = -0.629
#         (X5 -3): pval = 0.00000 | val =  0.443
#         (X6 -1): pval = 0.00000 | val =  0.250
#         (X4 -1): pval = 0.00000 | val = -0.239
#         (X5 -4): pval = 0.00000 | val = -0.239
#         (X4 -2): pval = 0.00000 | val =  0.236
#         (X5 -5): pval = 0.00000 | val = -0.188
#         (X6 -2): pval = 0.00000 | val = -0.157
#         (X3  0): pval = 0.00000 | val = -0.150 | unoriented link
#         (X6 -3): pval = 0.00000 | val = -0.148
#         (X6  0): pval = 0.00001 | val = -0.142 | unoriented link
#         (X7  0): pval = 0.00002 | val = -0.136 | unoriented link
#         (X2  0): pval = 0.00066 | val =  0.109 | unoriented link
#         (X3 -2): pval = 0.00667 | val = -0.087
#         (X7 -2): pval = 0.00754 | val =  0.085
#         (X4  0): pval = 0.01240 | val = -0.080 | unoriented link
#         (X8  0): pval = 0.01267 | val =  0.080 | unoriented link
#         (X4 -5): pval = 0.01597 | val =  0.077
#         (X0  0): pval = 0.01922 | val = -0.075 | unoriented link
#         (X3 -5): pval = 0.02164 | val = -0.074
#         (X9 -2): pval = 0.03774 | val = -0.067
#         (X8 -5): pval = 0.04361 | val =  0.065
#         (X1 -5): pval = 0.04394 | val =  0.065
#         (X0 -2): pval = 0.04705 | val = -0.064
#
#     Variable X6 has 19 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.882
#         (X6 -2): pval = 0.00000 | val = -0.660
#         (X6 -3): pval = 0.00000 | val =  0.443
#         (X7 -1): pval = 0.00000 | val =  0.282
#         (X6 -4): pval = 0.00000 | val = -0.241
#         (X7 -2): pval = 0.00000 | val = -0.198
#         (X5 -1): pval = 0.00000 | val = -0.172
#         (X5  0): pval = 0.00001 | val = -0.142 | unoriented link
#         (X4  0): pval = 0.00017 | val = -0.120 | unoriented link
#         (X6 -5): pval = 0.00022 | val =  0.118
#         (X8 -2): pval = 0.00138 | val =  0.102
#         (X7 -3): pval = 0.00618 | val = -0.087
#         (X9 -3): pval = 0.00811 | val =  0.085
#         (X8 -1): pval = 0.01017 | val = -0.082
#         (X3  0): pval = 0.01122 | val =  0.081 | unoriented link
#         (X3 -5): pval = 0.01741 | val =  0.076
#         (X9 -1): pval = 0.02949 | val = -0.070
#         (X8  0): pval = 0.02925 | val = -0.070 | unoriented link
#         (X7 -5): pval = 0.04851 | val = -0.063
#
#     Variable X7 has 18 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.866
#         (X7 -2): pval = 0.00000 | val = -0.627
#         (X7 -3): pval = 0.00000 | val =  0.431
#         (X7 -4): pval = 0.00000 | val = -0.261
#         (X8 -1): pval = 0.00000 | val =  0.246
#         (X6 -1): pval = 0.00000 | val = -0.202
#         (X6 -2): pval = 0.00000 | val =  0.179
#         (X7 -5): pval = 0.00000 | val = -0.155
#         (X8 -3): pval = 0.00001 | val = -0.142
#         (X9  0): pval = 0.00001 | val = -0.140 | unoriented link
#         (X5  0): pval = 0.00002 | val = -0.136 | unoriented link
#         (X9 -2): pval = 0.00015 | val =  0.121
#         (X0 -1): pval = 0.00040 | val = -0.113
#         (X8 -2): pval = 0.00051 | val = -0.111
#         (X8  0): pval = 0.00186 | val = -0.099 | unoriented link
#         (X4 -5): pval = 0.00330 | val =  0.094
#         (X3 -1): pval = 0.04298 | val = -0.065
#         (X1 -3): pval = 0.04526 | val = -0.064
#
#     Variable X8 has 28 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.876
#         (X8 -2): pval = 0.00000 | val = -0.629
#         (X8 -3): pval = 0.00000 | val =  0.449
#         (X8 -4): pval = 0.00000 | val = -0.285
#         (X9 -1): pval = 0.00000 | val =  0.262
#         (X9 -3): pval = 0.00000 | val = -0.195
#         (X8 -5): pval = 0.00000 | val = -0.192
#         (X0  0): pval = 0.00000 | val = -0.191 | unoriented link
#         (X7 -1): pval = 0.00000 | val = -0.181
#         (X0 -2): pval = 0.00000 | val =  0.147
#         (X9  0): pval = 0.00001 | val = -0.142 | unoriented link
#         (X9 -2): pval = 0.00004 | val = -0.131
#         (X0 -1): pval = 0.00060 | val = -0.109
#         (X6 -3): pval = 0.00110 | val = -0.104
#         (X7  0): pval = 0.00186 | val = -0.099 | unoriented link
#         (X6 -2): pval = 0.00194 | val = -0.099
#         (X1  0): pval = 0.00427 | val =  0.091 | unoriented link
#         (X5 -4): pval = 0.00437 | val =  0.091
#         (X4 -3): pval = 0.00467 | val =  0.090
#         (X1 -2): pval = 0.00569 | val = -0.088
#         (X6 -4): pval = 0.00944 | val = -0.083
#         (X5  0): pval = 0.01267 | val =  0.080 | unoriented link
#         (X5 -3): pval = 0.01443 | val =  0.078
#         (X3 -3): pval = 0.01545 | val = -0.077
#         (X1 -4): pval = 0.01550 | val =  0.077
#         (X0 -3): pval = 0.02359 | val =  0.072
#         (X6  0): pval = 0.02925 | val = -0.070 | unoriented link
#         (X3  0): pval = 0.04013 | val = -0.066 | unoriented link
#
#     Variable X9 has 22 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.871
#         (X9 -2): pval = 0.00000 | val = -0.652
#         (X9 -3): pval = 0.00000 | val =  0.459
#         (X0 -1): pval = 0.00000 | val =  0.292
#         (X9 -4): pval = 0.00000 | val = -0.270
#         (X0 -2): pval = 0.00000 | val = -0.233
#         (X8 -1): pval = 0.00000 | val = -0.197
#         (X8 -2): pval = 0.00000 | val =  0.173
#         (X9 -5): pval = 0.00000 | val =  0.160
#         (X8  0): pval = 0.00001 | val = -0.142 | unoriented link
#         (X7  0): pval = 0.00001 | val = -0.140 | unoriented link
#         (X0 -3): pval = 0.00006 | val = -0.128
#         (X1 -2): pval = 0.00012 | val =  0.123
#         (X1  0): pval = 0.00060 | val = -0.110 | unoriented link
#         (X1 -1): pval = 0.00065 | val = -0.109
#         (X0  0): pval = 0.00186 | val = -0.099 | unoriented link
#         (X3 -2): pval = 0.00194 | val = -0.099
#         (X6 -2): pval = 0.01084 | val = -0.081
#         (X7 -3): pval = 0.01291 | val =  0.080
#         (X8 -5): pval = 0.01433 | val =  0.078
#         (X2 -4): pval = 0.01848 | val =  0.075
#         (X7 -1): pval = 0.03049 | val = -0.069
# AUROC for Lorenz-96 with T=1000: 0.14166666666666666
# Saved VAR results to results_var_T_1000.npz
# Saved Lorenz-96 results to results_lorenz_T_1000.npz
