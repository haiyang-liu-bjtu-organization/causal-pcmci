# %%
# %cd /root/autodl-tmp/tigramite
# Out:
# /root/autodl-tmp/tigramite

# %%
import os

import numpy as np
from sklearn.metrics import roc_auc_score

from tigramite import data_processing as pp
from tigramite.independence_tests.parcorr import ParCorr
from tigramite.pcmci import PCMCI

# 定义参数
lag = 5
seed = 981  # 随机种子
tau_to_plot = 1  # 选择滞后时间 tau = 1


# 函数用于分析数据并计算 AUROC
def analyze_data(X, GC, var_names):
    # 创建 Tigramite 数据框
    dataframe = pp.DataFrame(X, var_names=var_names)

    # 初始化部分相关性检验对象
    parcorr = ParCorr(significance='analytic')

    # 初始化 PCMCI 对象
    pcmci = PCMCI(
        dataframe=dataframe,
        cond_ind_test=parcorr,
        verbosity=1
    )

    # 运行 PCMCI 以获取滞后依赖关系
    tau_max = lag  # 设置最大滞后时间
    results = pcmci.run_pcmci(tau_max=tau_max, pc_alpha=0.05)  # 设置显著性水平 (alpha)

    # 提取 p 值矩阵
    p_matrix = results['p_matrix']

    # 计算 AUROC（你可以根据自己的实际情况定义这个函数）
    auroc = compute_auroc(GC, p_matrix, tau_to_plot)

    return auroc, results


# AUROC 计算函数，假设我们定义一个简单的 AUROC 计算方式
def compute_auroc(GC, p_matrix, tau):
    # 这里假设 GC_true 和 p_matrix 的形状相同，并计算基于 p 值的 AUROC
    # 你可以根据实际需要来修改 AUROC 计算方法
    # 把 p_matrix 中的 p 值和真实的 GC 关系展平为一维
    p_values = p_matrix[:, :, tau].flatten()
    GC_values = GC.flatten()
    return roc_auc_score(GC_values, -p_values)  # 负 p 值越小说明越可能存在因果关系


# 读取指定的 .npz 文件路径
def process_files(input_files, output_base_folder):
    for file_path in input_files:
        print(f"Processing {file_path}...")

        # 载入数据
        data = np.load(file_path)
        X = data['X']  # 假设数据中有 'X' 和 'GC' 键
        GC = data['GC']

        # 生成变量名
        var_names = [f'X{i}' for i in range(X.shape[1])]

        # 分析数据
        auroc, results = analyze_data(X, GC, var_names)

        # 输出 AUROC
        print(f"AUROC for {file_path}: {auroc}")

        # 确定输出路径
        # 保留输入文件的目录结构，去掉原输入文件夹路径，保留子路径
        relative_path = os.path.relpath(file_path, start='datasets')  # 假设 "datasets" 是根目录
        output_folder = os.path.join(output_base_folder, os.path.dirname(relative_path))

        # 创建输出目录（如果不存在）
        os.makedirs(output_folder, exist_ok=True)

        # 构建保存结果的文件路径
        results_filename = os.path.join(output_folder, os.path.basename(file_path).replace('.npz', '_results.npz'))

        # 保存结果
        np.savez(results_filename, results=results, auroc=auroc)
        print(f"Saved results to {results_filename}")


# 设置输入文件夹路径数组
input_files_folder = [
    'datasets/lorenz/F10/time200',  # 示例文件路径，添加你实际的文件路径
    'datasets/lorenz/F10/time500',  # 示例文件路径，添加你实际的文件路径
    'datasets/lorenz/F10/time1000',  # 示例文件路径，添加你实际的文件路径
    'datasets/lorenz/F20/time200',  # 示例文件路径，添加你实际的文件路径
    'datasets/lorenz/F20/time500',  # 示例文件路径，添加你实际的文件路径
    'datasets/lorenz/F20/time1000',  # 示例文件路径，添加你实际的文件路径    
    'datasets/var/lag2-sp2/time200',
    'datasets/var/lag2-sp2/time500',
    'datasets/var/lag2-sp2/time1000',
    'datasets/var/lag3-sp2/time200',
    'datasets/var/lag3-sp2/time500',
    'datasets/var/lag3-sp2/time1000',
    'datasets/var/lag3-sp3/time200',
    'datasets/var/lag3-sp3/time500',
    'datasets/var/lag3-sp3/time1000',
    'datasets/var/lag3-sp4/time200',
    'datasets/var/lag3-sp4/time500',
    'datasets/var/lag3-sp4/time1000'
]

# 输出结果的根目录路径
output_base_folder = 'output/results'

# 构建 input_files 数组，收集每个文件夹中的 .npz 文件
input_files = []
for folder in input_files_folder:
    # 检查该文件夹是否存在
    if os.path.isdir(folder):
        # 获取该文件夹中的所有 .npz 文件
        npz_files = [folder + '/' + f for f in os.listdir(folder) if f.endswith('.npz')]
        input_files.extend(npz_files)
    else:
        print(f"Folder does not exist: {folder}")

# 处理所有文件
process_files(input_files, output_base_folder)
# Out:
# Processing datasets/lorenz/F10/time200/lorenz-584-F10-200.npz...
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 7 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.772
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.334
#         (X0 -4): max_pval = 0.00008, |min_val| =  0.284
#         (X7 -5): max_pval = 0.00036, |min_val| =  0.260
#         (X6 -2): max_pval = 0.00696, |min_val| =  0.196
#         (X2 -2): max_pval = 0.01172, |min_val| =  0.185
#         (X8 -1): max_pval = 0.04583, |min_val| =  0.147
#
#     Variable X1 has 5 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.846
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.550
#         (X1 -3): max_pval = 0.00003, |min_val| =  0.295
#         (X8 -5): max_pval = 0.00048, |min_val| =  0.253
#         (X1 -4): max_pval = 0.04629, |min_val| =  0.145
#
#     Variable X2 has 5 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.741
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.395
#         (X8 -3): max_pval = 0.00472, |min_val| =  0.206
#         (X3 -1): max_pval = 0.03689, |min_val| =  0.153
#         (X0 -3): max_pval = 0.03735, |min_val| =  0.152
#
#     Variable X3 has 6 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.751
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.432
#         (X4 -1): max_pval = 0.01290, |min_val| =  0.183
#         (X2 -1): max_pval = 0.01925, |min_val| =  0.171
#         (X1 -2): max_pval = 0.02134, |min_val| =  0.168
#         (X9 -3): max_pval = 0.02199, |min_val| =  0.167
#
#     Variable X4 has 4 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.763
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.412
#         (X1 -5): max_pval = 0.00000, |min_val| =  0.348
#         (X0 -3): max_pval = 0.03644, |min_val| =  0.153
#
#     Variable X5 has 5 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.756
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.428
#         (X6 -1): max_pval = 0.00119, |min_val| =  0.236
#         (X2 -5): max_pval = 0.01677, |min_val| =  0.175
#         (X1 -4): max_pval = 0.04994, |min_val| =  0.144
#
#     Variable X6 has 6 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.864
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.601
#         (X6 -3): max_pval = 0.00001, |min_val| =  0.321
#         (X0 -3): max_pval = 0.01660, |min_val| =  0.176
#         (X7 -1): max_pval = 0.03407, |min_val| =  0.154
#         (X3 -4): max_pval = 0.03718, |min_val| =  0.153
#
#     Variable X7 has 5 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.786
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.502
#         (X8 -1): max_pval = 0.00026, |min_val| =  0.265
#         (X7 -3): max_pval = 0.00895, |min_val| =  0.189
#         (X4 -4): max_pval = 0.02329, |min_val| =  0.166
#
#     Variable X8 has 5 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.834
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.448
#         (X8 -4): max_pval = 0.00398, |min_val| =  0.209
#         (X6 -1): max_pval = 0.00461, |min_val| =  0.207
#         (X7 -4): max_pval = 0.02141, |min_val| =  0.168
#
#     Variable X9 has 5 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.894
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.640
#         (X9 -3): max_pval = 0.00000, |min_val| =  0.350
#         (X6 -4): max_pval = 0.00003, |min_val| =  0.299
#         (X0 -1): max_pval = 0.00065, |min_val| =  0.247
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 16 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.888
#         (X0 -2): pval = 0.00000 | val = -0.707
#         (X0 -3): pval = 0.00000 | val =  0.485
#         (X0 -4): pval = 0.00001 | val =  0.332
#         (X2  0): pval = 0.00002 | val = -0.316 | unoriented link
#         (X0 -5): pval = 0.00004 | val = -0.303
#         (X1 -1): pval = 0.00009 | val =  0.290
#         (X2 -2): pval = 0.00507 | val =  0.209
#         (X3 -5): pval = 0.00781 | val = -0.199
#         (X7 -5): pval = 0.00958 | val =  0.193
#         (X9 -4): pval = 0.01095 | val =  0.190
#         (X5 -2): pval = 0.01578 | val = -0.181
#         (X5  0): pval = 0.01618 | val =  0.180 | unoriented link
#         (X8 -5): pval = 0.02785 | val = -0.165
#         (X1 -3): pval = 0.03374 | val = -0.159
#         (X4 -5): pval = 0.04256 | val =  0.152
#
#     Variable X1 has 14 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.861
#         (X1 -2): pval = 0.00000 | val = -0.653
#         (X1 -3): pval = 0.00000 | val =  0.435
#         (X4  0): pval = 0.00000 | val =  0.366 | unoriented link
#         (X4 -3): pval = 0.00001 | val =  0.316
#         (X3 -2): pval = 0.00003 | val =  0.304
#         (X1 -4): pval = 0.00030 | val = -0.266
#         (X9  0): pval = 0.00060 | val = -0.253 | unoriented link
#         (X3  0): pval = 0.00105 | val = -0.242 | unoriented link
#         (X3 -3): pval = 0.00603 | val = -0.205
#         (X1 -5): pval = 0.01827 | val =  0.176
#         (X0 -1): pval = 0.03226 | val = -0.161
#         (X3 -4): pval = 0.03187 | val = -0.160
#         (X0 -3): pval = 0.04733 | val = -0.149
#
#     Variable X2 has 18 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.841
#         (X2 -2): pval = 0.00000 | val = -0.644
#         (X2 -3): pval = 0.00000 | val =  0.453
#         (X1 -1): pval = 0.00000 | val = -0.407
#         (X0  0): pval = 0.00002 | val = -0.316 | unoriented link
#         (X1 -3): pval = 0.00002 | val =  0.316
#         (X2 -4): pval = 0.00015 | val =  0.279
#         (X3 -2): pval = 0.00235 | val = -0.226
#         (X3 -1): pval = 0.00269 | val =  0.222
#         (X0 -3): pval = 0.00683 | val = -0.202
#         (X4 -1): pval = 0.01063 | val = -0.189
#         (X3 -3): pval = 0.01205 | val = -0.187
#         (X1 -4): pval = 0.01214 | val =  0.187
#         (X3 -5): pval = 0.01548 | val =  0.181
#         (X9 -4): pval = 0.01598 | val = -0.179
#         (X4  0): pval = 0.02369 | val = -0.168 | unoriented link
#         (X0 -5): pval = 0.03335 | val =  0.160
#         (X8 -1): pval = 0.03600 | val =  0.156
#
#     Variable X3 has 16 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.866
#         (X3 -2): pval = 0.00000 | val = -0.573
#         (X4 -1): pval = 0.00000 | val =  0.379
#         (X3 -3): pval = 0.00000 | val =  0.374
#         (X5 -3): pval = 0.00006 | val =  0.295
#         (X5 -1): pval = 0.00007 | val = -0.294
#         (X1  0): pval = 0.00105 | val = -0.242 | unoriented link
#         (X4 -3): pval = 0.00136 | val = -0.237
#         (X3 -4): pval = 0.00820 | val =  0.198
#         (X0 -3): pval = 0.00896 | val =  0.196
#         (X6 -1): pval = 0.01281 | val =  0.186
#         (X4  0): pval = 0.01248 | val = -0.185 | unoriented link
#         (X1 -2): pval = 0.01385 | val = -0.183
#         (X4 -2): pval = 0.01553 | val = -0.180
#         (X0 -1): pval = 0.04076 | val = -0.154
#         (X8 -3): pval = 0.04464 | val = -0.150
#
#     Variable X4 has 19 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.876
#         (X4 -2): pval = 0.00000 | val = -0.690
#         (X4 -3): pval = 0.00000 | val =  0.479
#         (X3 -1): pval = 0.00000 | val = -0.406
#         (X1  0): pval = 0.00000 | val =  0.366 | unoriented link
#         (X6 -1): pval = 0.00000 | val = -0.339
#         (X4 -4): pval = 0.00003 | val =  0.303
#         (X5 -2): pval = 0.00044 | val =  0.259
#         (X7 -1): pval = 0.00307 | val =  0.219
#         (X7  0): pval = 0.00638 | val =  0.202 | unoriented link
#         (X5 -4): pval = 0.00711 | val = -0.199
#         (X1 -5): pval = 0.00754 | val =  0.197
#         (X4 -5): pval = 0.01098 | val =  0.188
#         (X3  0): pval = 0.01248 | val = -0.185 | unoriented link
#         (X5  0): pval = 0.02132 | val = -0.171 | unoriented link
#         (X2  0): pval = 0.02369 | val = -0.168 | unoriented link
#         (X6 -3): pval = 0.04131 | val =  0.152
#         (X2 -5): pval = 0.04122 | val = -0.152
#         (X6 -2): pval = 0.04830 | val = -0.147
#
#     Variable X5 has 14 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.855
#         (X5 -2): pval = 0.00000 | val = -0.699
#         (X5 -3): pval = 0.00000 | val =  0.570
#         (X5 -4): pval = 0.00004 | val =  0.302
#         (X2 -5): pval = 0.00004 | val =  0.300
#         (X6  0): pval = 0.00103 | val = -0.243 | unoriented link
#         (X6 -3): pval = 0.00414 | val = -0.213
#         (X6 -1): pval = 0.00667 | val =  0.202
#         (X8 -2): pval = 0.01270 | val =  0.185
#         (X0  0): pval = 0.01618 | val =  0.180 | unoriented link
#         (X6 -4): pval = 0.02045 | val = -0.173
#         (X4  0): pval = 0.02132 | val = -0.171 | unoriented link
#         (X0 -5): pval = 0.02267 | val = -0.171
#         (X8  0): pval = 0.04833 | val = -0.147 | unoriented link
#
#     Variable X6 has 14 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.880
#         (X6 -2): pval = 0.00000 | val = -0.646
#         (X6 -3): pval = 0.00000 | val =  0.480
#         (X7 -3): pval = 0.00002 | val = -0.312
#         (X6 -4): pval = 0.00023 | val = -0.273
#         (X4 -2): pval = 0.00102 | val = -0.243
#         (X5  0): pval = 0.00103 | val = -0.243 | unoriented link
#         (X5 -1): pval = 0.00347 | val = -0.217
#         (X6 -5): pval = 0.00374 | val = -0.216
#         (X7 -1): pval = 0.00646 | val =  0.202
#         (X7  0): pval = 0.01079 | val = -0.190 | unoriented link
#         (X2 -5): pval = 0.01332 | val = -0.185
#         (X3 -2): pval = 0.02484 | val =  0.168
#         (X0 -5): pval = 0.04455 | val =  0.151
#
#     Variable X7 has 12 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.885
#         (X7 -2): pval = 0.00000 | val = -0.666
#         (X7 -3): pval = 0.00000 | val =  0.437
#         (X7 -4): pval = 0.00126 | val = -0.239
#         (X7 -5): pval = 0.00349 | val = -0.217
#         (X8 -3): pval = 0.00453 | val = -0.211
#         (X8 -1): pval = 0.00590 | val =  0.204
#         (X4  0): pval = 0.00638 | val =  0.202 | unoriented link
#         (X6  0): pval = 0.01079 | val = -0.190 | unoriented link
#         (X8  0): pval = 0.02836 | val = -0.163 | unoriented link
#         (X9  0): pval = 0.03708 | val = -0.156 | unoriented link
#         (X8 -5): pval = 0.03860 | val =  0.154
#
#     Variable X8 has 12 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.901
#         (X8 -2): pval = 0.00000 | val = -0.708
#         (X8 -3): pval = 0.00000 | val =  0.511
#         (X8 -5): pval = 0.00013 | val = -0.281
#         (X8 -4): pval = 0.00024 | val =  0.270
#         (X9  0): pval = 0.00043 | val = -0.260 | unoriented link
#         (X9 -2): pval = 0.00220 | val =  0.227
#         (X7  0): pval = 0.02836 | val = -0.163 | unoriented link
#         (X1 -3): pval = 0.03076 | val =  0.161
#         (X5 -2): pval = 0.03163 | val =  0.160
#         (X2 -4): pval = 0.03330 | val =  0.159
#         (X5  0): pval = 0.04833 | val = -0.147 | unoriented link
#
#     Variable X9 has 14 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.917
#         (X9 -2): pval = 0.00000 | val = -0.711
#         (X9 -3): pval = 0.00000 | val =  0.490
#         (X9 -5): pval = 0.00039 | val = -0.261
#         (X8  0): pval = 0.00043 | val = -0.260 | unoriented link
#         (X9 -4): pval = 0.00047 | val = -0.258
#         (X1  0): pval = 0.00060 | val = -0.253 | unoriented link
#         (X2 -2): pval = 0.00144 | val =  0.236
#         (X8 -1): pval = 0.00466 | val = -0.210
#         (X6 -4): pval = 0.00680 | val =  0.201
#         (X4 -3): pval = 0.00680 | val = -0.200
#         (X0 -4): pval = 0.03466 | val = -0.158
#         (X7  0): pval = 0.03708 | val = -0.156 | unoriented link
#         (X4 -2): pval = 0.04125 | val = -0.152
# AUROC for datasets/lorenz/F10/time200/lorenz-584-F10-200.npz: 0.8099999999999999
# Saved results to output/results/lorenz/F10/time200/lorenz-584-F10-200_results.npz
# Processing datasets/lorenz/F10/time200/lorenz-381-F10-200.npz...
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 4 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.827
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.479
#         (X0 -3): max_pval = 0.00826, |min_val| =  0.191
#         (X9 -5): max_pval = 0.04025, |min_val| =  0.149
#
#     Variable X1 has 6 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.852
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.547
#         (X1 -3): max_pval = 0.00004, |min_val| =  0.293
#         (X8 -5): max_pval = 0.00381, |min_val| =  0.209
#         (X2 -1): max_pval = 0.00690, |min_val| =  0.196
#         (X1 -4): max_pval = 0.02914, |min_val| =  0.158
#
#     Variable X2 has 4 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.814
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.448
#         (X3 -1): max_pval = 0.03026, |min_val| =  0.159
#         (X2 -3): max_pval = 0.03664, |min_val| =  0.152
#
#     Variable X3 has 6 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.866
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.599
#         (X3 -3): max_pval = 0.00000, |min_val| =  0.361
#         (X3 -4): max_pval = 0.00228, |min_val| =  0.221
#         (X0 -5): max_pval = 0.00858, |min_val| =  0.192
#         (X2 -1): max_pval = 0.02166, |min_val| =  0.167
#
#     Variable X4 has 5 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.863
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.594
#         (X4 -3): max_pval = 0.00000, |min_val| =  0.352
#         (X4 -4): max_pval = 0.00618, |min_val| =  0.199
#         (X2 -1): max_pval = 0.04956, |min_val| =  0.143
#
#     Variable X5 has 3 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.791
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.378
#         (X2 -2): max_pval = 0.02555, |min_val| =  0.163
#
#     Variable X6 has 5 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.837
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.505
#         (X6 -3): max_pval = 0.00172, |min_val| =  0.226
#         (X4 -2): max_pval = 0.04277, |min_val| =  0.148
#         (X7 -1): max_pval = 0.04425, |min_val| =  0.147
#
#     Variable X7 has 4 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.849
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.534
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.338
#         (X7 -3): max_pval = 0.00046, |min_val| =  0.252
#
#     Variable X8 has 4 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.806
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.434
#         (X9 -1): max_pval = 0.00312, |min_val| =  0.215
#         (X0 -2): max_pval = 0.04923, |min_val| =  0.144
#
#     Variable X9 has 5 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.826
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.504
#         (X9 -3): max_pval = 0.00078, |min_val| =  0.243
#         (X7 -2): max_pval = 0.02357, |min_val| =  0.165
#         (X0 -1): max_pval = 0.02398, |min_val| =  0.165
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 8 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.871
#         (X0 -2): pval = 0.00000 | val = -0.622
#         (X0 -3): pval = 0.00000 | val =  0.372
#         (X1 -1): pval = 0.00008 | val =  0.289
#         (X0 -4): pval = 0.00758 | val = -0.197
#         (X1 -4): pval = 0.01648 | val = -0.179
#         (X2  0): pval = 0.03662 | val = -0.155 | unoriented link
#         (X8  0): pval = 0.04881 | val = -0.146 | unoriented link
#
#     Variable X1 has 15 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.873
#         (X1 -2): pval = 0.00000 | val = -0.626
#         (X2 -1): pval = 0.00000 | val =  0.405
#         (X1 -3): pval = 0.00000 | val =  0.382
#         (X2 -2): pval = 0.00000 | val = -0.359
#         (X7 -4): pval = 0.00293 | val = -0.220
#         (X9  0): pval = 0.00458 | val = -0.211 | unoriented link
#         (X3 -2): pval = 0.00981 | val =  0.193
#         (X0 -1): pval = 0.00956 | val = -0.193
#         (X0 -3): pval = 0.02401 | val = -0.168
#         (X4 -3): pval = 0.02514 | val =  0.167
#         (X7 -3): pval = 0.03101 | val =  0.161
#         (X6 -4): pval = 0.03212 | val =  0.160
#         (X1 -4): pval = 0.03216 | val = -0.160
#         (X5 -2): pval = 0.04078 | val = -0.152
#
#     Variable X2 has 15 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.880
#         (X2 -2): pval = 0.00000 | val = -0.676
#         (X2 -3): pval = 0.00000 | val =  0.460
#         (X2 -5): pval = 0.00000 | val = -0.336
#         (X1 -1): pval = 0.00003 | val = -0.308
#         (X2 -4): pval = 0.00032 | val = -0.264
#         (X7 -5): pval = 0.00129 | val =  0.237
#         (X4 -2): pval = 0.00269 | val =  0.221
#         (X9  0): pval = 0.00411 | val =  0.212 | unoriented link
#         (X5 -3): pval = 0.01200 | val =  0.185
#         (X8 -4): pval = 0.01419 | val = -0.182
#         (X8 -5): pval = 0.02440 | val =  0.167
#         (X3 -3): pval = 0.03519 | val = -0.157
#         (X0  0): pval = 0.03662 | val = -0.155 | unoriented link
#         (X4 -4): pval = 0.04116 | val = -0.152
#
#     Variable X3 has 17 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.869
#         (X3 -2): pval = 0.00000 | val = -0.675
#         (X3 -3): pval = 0.00000 | val =  0.477
#         (X4 -1): pval = 0.00000 | val =  0.370
#         (X3 -4): pval = 0.00001 | val = -0.330
#         (X1 -2): pval = 0.00030 | val = -0.268
#         (X6 -3): pval = 0.00084 | val =  0.247
#         (X3 -5): pval = 0.00152 | val =  0.236
#         (X5  0): pval = 0.00479 | val = -0.209 | unoriented link
#         (X9 -3): pval = 0.00571 | val =  0.206
#         (X8 -3): pval = 0.00671 | val = -0.201
#         (X7 -4): pval = 0.00820 | val =  0.196
#         (X7 -3): pval = 0.00824 | val =  0.196
#         (X8 -2): pval = 0.01333 | val = -0.184
#         (X7 -2): pval = 0.02357 | val = -0.169
#         (X8 -4): pval = 0.04197 | val =  0.152
#         (X1 -3): pval = 0.04985 | val = -0.147
#
#     Variable X4 has 16 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.872
#         (X4 -2): pval = 0.00000 | val = -0.662
#         (X4 -3): pval = 0.00000 | val =  0.490
#         (X5 -1): pval = 0.00000 | val =  0.488
#         (X4 -4): pval = 0.00000 | val = -0.360
#         (X6 -2): pval = 0.00000 | val =  0.339
#         (X6  0): pval = 0.00002 | val = -0.310 | unoriented link
#         (X7 -3): pval = 0.00005 | val =  0.297
#         (X4 -5): pval = 0.00075 | val =  0.249
#         (X7 -1): pval = 0.00073 | val = -0.249
#         (X5 -5): pval = 0.00128 | val = -0.237
#         (X3 -1): pval = 0.00217 | val = -0.228
#         (X0 -5): pval = 0.01132 | val =  0.188
#         (X8 -3): pval = 0.02456 | val =  0.167
#         (X6 -3): pval = 0.03447 | val = -0.158
#         (X8 -1): pval = 0.04625 | val = -0.148
#
#     Variable X5 has 15 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.862
#         (X5 -2): pval = 0.00000 | val = -0.654
#         (X5 -3): pval = 0.00000 | val =  0.447
#         (X6 -1): pval = 0.00000 | val =  0.380
#         (X4 -1): pval = 0.00001 | val = -0.327
#         (X7  0): pval = 0.00005 | val = -0.297 | unoriented link
#         (X5 -4): pval = 0.00019 | val =  0.272
#         (X6  0): pval = 0.00028 | val = -0.267 | unoriented link
#         (X7 -2): pval = 0.00050 | val =  0.255
#         (X6 -3): pval = 0.00225 | val = -0.225
#         (X8 -1): pval = 0.00412 | val = -0.211
#         (X3  0): pval = 0.00479 | val = -0.209 | unoriented link
#         (X7 -4): pval = 0.01308 | val = -0.183
#         (X7 -1): pval = 0.01784 | val = -0.175
#         (X6 -2): pval = 0.01950 | val =  0.173
#
#     Variable X6 has 14 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.875
#         (X6 -2): pval = 0.00000 | val = -0.624
#         (X6 -3): pval = 0.00000 | val =  0.416
#         (X7 -1): pval = 0.00001 | val =  0.327
#         (X4  0): pval = 0.00002 | val = -0.310 | unoriented link
#         (X7 -2): pval = 0.00009 | val = -0.287
#         (X8  0): pval = 0.00020 | val = -0.273 | unoriented link
#         (X6 -4): pval = 0.00023 | val = -0.271
#         (X5  0): pval = 0.00028 | val = -0.267 | unoriented link
#         (X5 -2): pval = 0.00128 | val =  0.237
#         (X0 -2): pval = 0.00328 | val = -0.217
#         (X8 -2): pval = 0.00529 | val =  0.206
#         (X7 -3): pval = 0.02713 | val = -0.164
#         (X1 -3): pval = 0.04672 | val = -0.149
#
#     Variable X7 has 12 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.861
#         (X8 -1): pval = 0.00000 | val =  0.597
#         (X7 -2): pval = 0.00000 | val = -0.544
#         (X8 -2): pval = 0.00000 | val = -0.538
#         (X7 -3): pval = 0.00000 | val =  0.394
#         (X9 -2): pval = 0.00001 | val =  0.322
#         (X5  0): pval = 0.00005 | val = -0.297 | unoriented link
#         (X8 -3): pval = 0.00072 | val = -0.249
#         (X7 -4): pval = 0.00175 | val = -0.230
#         (X9  0): pval = 0.01142 | val = -0.187 | unoriented link
#         (X0 -4): pval = 0.01996 | val = -0.172
#         (X1 -5): pval = 0.02575 | val = -0.166
#
#     Variable X8 has 16 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.855
#         (X8 -2): pval = 0.00000 | val = -0.628
#         (X7 -1): pval = 0.00000 | val = -0.479
#         (X9 -1): pval = 0.00000 | val =  0.429
#         (X8 -3): pval = 0.00000 | val =  0.410
#         (X9 -3): pval = 0.00001 | val = -0.318
#         (X0 -2): pval = 0.00005 | val =  0.295
#         (X8 -4): pval = 0.00010 | val =  0.285
#         (X9 -2): pval = 0.00012 | val = -0.282
#         (X6  0): pval = 0.00020 | val = -0.273 | unoriented link
#         (X1 -3): pval = 0.00036 | val =  0.263
#         (X0 -3): pval = 0.00053 | val = -0.254
#         (X9  0): pval = 0.00140 | val = -0.235 | unoriented link
#         (X7 -3): pval = 0.01027 | val =  0.190
#         (X6 -5): pval = 0.04711 | val = -0.148
#         (X0  0): pval = 0.04881 | val = -0.146 | unoriented link
#
#     Variable X9 has 11 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.825
#         (X9 -2): pval = 0.00000 | val = -0.470
#         (X0 -1): pval = 0.00000 | val =  0.386
#         (X0 -2): pval = 0.00001 | val = -0.323
#         (X8  0): pval = 0.00140 | val = -0.235 | unoriented link
#         (X9 -3): pval = 0.00157 | val =  0.233
#         (X2  0): pval = 0.00411 | val =  0.212 | unoriented link
#         (X1  0): pval = 0.00458 | val = -0.211 | unoriented link
#         (X8 -1): pval = 0.00764 | val = -0.197
#         (X7  0): pval = 0.01142 | val = -0.187 | unoriented link
#         (X1 -1): pval = 0.04215 | val = -0.152
# AUROC for datasets/lorenz/F10/time200/lorenz-381-F10-200.npz: 0.8729166666666667
# Saved results to output/results/lorenz/F10/time200/lorenz-381-F10-200_results.npz
# Processing datasets/lorenz/F10/time200/lorenz-169-F10-200.npz...
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 5 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.843
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.505
#         (X1 -1): max_pval = 0.00243, |min_val| =  0.220
#         (X8 -1): max_pval = 0.01205, |min_val| =  0.184
#         (X0 -3): max_pval = 0.01138, |min_val| =  0.183
#
#     Variable X1 has 3 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.776
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.411
#         (X2 -1): max_pval = 0.00269, |min_val| =  0.219
#
#     Variable X2 has 4 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.839
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.492
#         (X2 -3): max_pval = 0.01144, |min_val| =  0.183
#         (X0 -1): max_pval = 0.04673, |min_val| =  0.146
#
#     Variable X3 has 5 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.858
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.548
#         (X4 -1): max_pval = 0.00055, |min_val| =  0.251
#         (X3 -3): max_pval = 0.00114, |min_val| =  0.234
#         (X5 -3): max_pval = 0.01260, |min_val| =  0.182
#
#     Variable X4 has 2 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.829
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.452
#
#     Variable X5 has 3 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.740
#         (X5 -2): max_pval = 0.00001, |min_val| =  0.319
#         (X4 -4): max_pval = 0.00472, |min_val| =  0.205
#
#     Variable X6 has 5 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.854
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.576
#         (X6 -3): max_pval = 0.00001, |min_val| =  0.319
#         (X7 -1): max_pval = 0.00618, |min_val| =  0.199
#         (X4 -1): max_pval = 0.01056, |min_val| =  0.186
#
#     Variable X7 has 4 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.740
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.424
#         (X5 -1): max_pval = 0.00305, |min_val| =  0.215
#         (X8 -1): max_pval = 0.00879, |min_val| =  0.191
#
#     Variable X8 has 4 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.811
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.431
#         (X5 -3): max_pval = 0.01044, |min_val| =  0.187
#         (X6 -2): max_pval = 0.03719, |min_val| =  0.153
#
#     Variable X9 has 5 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.746
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.382
#         (X7 -1): max_pval = 0.00524, |min_val| =  0.203
#         (X0 -1): max_pval = 0.00619, |min_val| =  0.200
#         (X9 -4): max_pval = 0.03465, |min_val| =  0.154
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 12 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.878
#         (X0 -2): pval = 0.00000 | val = -0.593
#         (X0 -3): pval = 0.00000 | val =  0.359
#         (X9 -1): pval = 0.00004 | val = -0.299
#         (X1 -1): pval = 0.00034 | val =  0.262
#         (X1 -5): pval = 0.00295 | val = -0.219
#         (X4 -1): pval = 0.00382 | val = -0.213
#         (X8 -5): pval = 0.01581 | val = -0.179
#         (X4  0): pval = 0.01635 | val = -0.177 | unoriented link
#         (X8  0): pval = 0.02146 | val = -0.170 | unoriented link
#         (X1 -4): pval = 0.03190 | val = -0.159
#         (X8 -1): pval = 0.04020 | val = -0.152
#
#     Variable X1 has 13 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.874
#         (X1 -2): pval = 0.00000 | val = -0.631
#         (X1 -3): pval = 0.00000 | val =  0.461
#         (X2 -4): pval = 0.00003 | val = -0.305
#         (X6  0): pval = 0.00039 | val =  0.260 | unoriented link
#         (X3 -1): pval = 0.00065 | val = -0.250
#         (X8  0): pval = 0.00141 | val =  0.234 | unoriented link
#         (X2 -3): pval = 0.00255 | val = -0.222
#         (X2  0): pval = 0.00308 | val = -0.217 | unoriented link
#         (X1 -4): pval = 0.00492 | val =  0.207
#         (X3  0): pval = 0.01396 | val = -0.182 | unoriented link
#         (X9 -4): pval = 0.01859 | val = -0.174
#         (X4  0): pval = 0.02754 | val =  0.162 | unoriented link
#
#     Variable X2 has 8 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.901
#         (X2 -2): pval = 0.00000 | val = -0.694
#         (X2 -3): pval = 0.00000 | val =  0.440
#         (X2 -4): pval = 0.00105 | val = -0.241
#         (X1  0): pval = 0.00308 | val = -0.217 | unoriented link
#         (X4 -4): pval = 0.03001 | val =  0.160
#         (X2 -5): pval = 0.03971 | val = -0.153
#         (X3 -2): pval = 0.04075 | val =  0.152
#
#     Variable X3 has 11 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.889
#         (X3 -2): pval = 0.00000 | val = -0.624
#         (X3 -3): pval = 0.00000 | val =  0.446
#         (X4 -1): pval = 0.00000 | val =  0.396
#         (X3 -4): pval = 0.00023 | val = -0.272
#         (X4 -3): pval = 0.00066 | val = -0.249
#         (X4 -2): pval = 0.00196 | val = -0.227
#         (X5 -3): pval = 0.01014 | val =  0.190
#         (X1  0): pval = 0.01396 | val = -0.182 | unoriented link
#         (X3 -5): pval = 0.01486 | val = -0.181
#         (X1 -3): pval = 0.01564 | val = -0.179
#
#     Variable X4 has 18 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.891
#         (X4 -2): pval = 0.00000 | val = -0.686
#         (X4 -3): pval = 0.00000 | val =  0.399
#         (X3 -1): pval = 0.00000 | val = -0.359
#         (X6  0): pval = 0.00016 | val = -0.275 | unoriented link
#         (X4 -5): pval = 0.00056 | val =  0.251
#         (X5 -1): pval = 0.00132 | val =  0.234
#         (X4 -4): pval = 0.00232 | val =  0.222
#         (X6 -2): pval = 0.00369 | val =  0.214
#         (X6 -1): pval = 0.00415 | val = -0.210
#         (X0  0): pval = 0.01635 | val = -0.177 | unoriented link
#         (X9 -2): pval = 0.01698 | val = -0.176
#         (X9  0): pval = 0.01856 | val =  0.174 | unoriented link
#         (X5 -5): pval = 0.01861 | val = -0.173
#         (X1 -4): pval = 0.02708 | val =  0.163
#         (X1  0): pval = 0.02754 | val =  0.162 | unoriented link
#         (X9 -3): pval = 0.03908 | val = -0.153
#         (X5 -4): pval = 0.04445 | val = -0.148
#
#     Variable X5 has 17 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.842
#         (X5 -2): pval = 0.00000 | val = -0.685
#         (X5 -3): pval = 0.00000 | val =  0.500
#         (X5 -4): pval = 0.00044 | val =  0.256
#         (X4 -1): pval = 0.00056 | val = -0.251
#         (X9 -2): pval = 0.00210 | val = -0.227
#         (X7  0): pval = 0.00731 | val = -0.197 | unoriented link
#         (X0 -1): pval = 0.00939 | val =  0.192
#         (X7 -2): pval = 0.01156 | val =  0.186
#         (X0 -5): pval = 0.01272 | val =  0.184
#         (X8 -3): pval = 0.01342 | val =  0.182
#         (X6 -1): pval = 0.01933 | val =  0.173
#         (X6  0): pval = 0.02199 | val = -0.170 | unoriented link
#         (X6 -3): pval = 0.02578 | val = -0.165
#         (X2 -1): pval = 0.02788 | val = -0.163
#         (X8 -5): pval = 0.03498 | val = -0.156
#         (X4 -3): pval = 0.04292 | val =  0.149
#
#     Variable X6 has 16 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.856
#         (X6 -2): pval = 0.00000 | val = -0.582
#         (X6 -3): pval = 0.00000 | val =  0.403
#         (X4  0): pval = 0.00016 | val = -0.275 | unoriented link
#         (X1  0): pval = 0.00039 | val =  0.260 | unoriented link
#         (X7 -1): pval = 0.00155 | val =  0.233
#         (X6 -4): pval = 0.00251 | val = -0.224
#         (X5 -1): pval = 0.00798 | val = -0.196
#         (X1 -2): pval = 0.00852 | val = -0.194
#         (X0 -2): pval = 0.01038 | val = -0.191
#         (X5  0): pval = 0.02199 | val = -0.170 | unoriented link
#         (X9 -2): pval = 0.02355 | val =  0.169
#         (X0 -4): pval = 0.03062 | val =  0.161
#         (X2 -1): pval = 0.03289 | val = -0.159
#         (X7 -3): pval = 0.03910 | val = -0.154
#         (X7 -2): pval = 0.04892 | val = -0.147
#
#     Variable X7 has 17 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.848
#         (X7 -2): pval = 0.00000 | val = -0.586
#         (X8 -1): pval = 0.00000 | val =  0.498
#         (X7 -3): pval = 0.00000 | val =  0.349
#         (X8 -3): pval = 0.00001 | val = -0.322
#         (X8 -2): pval = 0.00003 | val = -0.305
#         (X9 -2): pval = 0.00010 | val =  0.286
#         (X5 -1): pval = 0.00014 | val = -0.277
#         (X7 -4): pval = 0.00141 | val =  0.235
#         (X2 -1): pval = 0.00169 | val =  0.231
#         (X7 -5): pval = 0.00285 | val =  0.220
#         (X4 -5): pval = 0.00437 | val =  0.209
#         (X6 -1): pval = 0.00508 | val = -0.207
#         (X5  0): pval = 0.00731 | val = -0.197 | unoriented link
#         (X8 -4): pval = 0.01755 | val = -0.176
#         (X0 -2): pval = 0.02096 | val = -0.172
#         (X5 -5): pval = 0.04293 | val = -0.150
#
#     Variable X8 has 18 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.869
#         (X8 -2): pval = 0.00000 | val = -0.695
#         (X7 -1): pval = 0.00000 | val = -0.516
#         (X8 -3): pval = 0.00000 | val =  0.391
#         (X8 -4): pval = 0.00000 | val =  0.356
#         (X0 -2): pval = 0.00033 | val =  0.264
#         (X8 -5): pval = 0.00044 | val =  0.258
#         (X7 -3): pval = 0.00087 | val =  0.245
#         (X9 -1): pval = 0.00144 | val =  0.235
#         (X1  0): pval = 0.00141 | val =  0.234 | unoriented link
#         (X7 -4): pval = 0.00493 | val =  0.208
#         (X1 -3): pval = 0.01275 | val =  0.184
#         (X0 -1): pval = 0.01350 | val = -0.183
#         (X9 -2): pval = 0.01415 | val =  0.182
#         (X1 -4): pval = 0.01912 | val =  0.173
#         (X0  0): pval = 0.02146 | val = -0.170 | unoriented link
#         (X2 -4): pval = 0.02715 | val = -0.164
#         (X5 -3): pval = 0.03373 | val =  0.157
#
#     Variable X9 has 9 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.868
#         (X9 -2): pval = 0.00000 | val = -0.623
#         (X9 -3): pval = 0.00000 | val =  0.472
#         (X0 -1): pval = 0.00186 | val =  0.230
#         (X8 -1): pval = 0.00419 | val = -0.212
#         (X9 -4): pval = 0.01873 | val =  0.175
#         (X4  0): pval = 0.01856 | val =  0.174 | unoriented link
#         (X9 -5): pval = 0.02036 | val = -0.173
#         (X0 -3): pval = 0.04231 | val = -0.152
# AUROC for datasets/lorenz/F10/time200/lorenz-169-F10-200.npz: 0.8929166666666667
# Saved results to output/results/lorenz/F10/time200/lorenz-169-F10-200_results.npz
# Processing datasets/lorenz/F10/time200/lorenz-594-F10-200.npz...
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 3 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.785
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.466
#         (X7 -5): max_pval = 0.02332, |min_val| =  0.166
#
#     Variable X1 has 3 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.781
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.450
#         (X2 -1): max_pval = 0.00017, |min_val| =  0.271
#
#     Variable X2 has 6 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.807
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.497
#         (X3 -1): max_pval = 0.00006, |min_val| =  0.288
#         (X1 -1): max_pval = 0.01041, |min_val| =  0.187
#         (X7 -5): max_pval = 0.03085, |min_val| =  0.158
#         (X2 -3): max_pval = 0.02925, |min_val| =  0.158
#
#     Variable X3 has 5 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.713
#         (X4 -1): max_pval = 0.00049, |min_val| =  0.253
#         (X3 -2): max_pval = 0.00081, |min_val| =  0.241
#         (X9 -4): max_pval = 0.00468, |min_val| =  0.205
#         (X4 -2): max_pval = 0.04830, |min_val| =  0.144
#
#     Variable X4 has 5 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.761
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.450
#         (X1 -5): max_pval = 0.00007, |min_val| =  0.286
#         (X5 -1): max_pval = 0.00073, |min_val| =  0.245
#         (X4 -3): max_pval = 0.01114, |min_val| =  0.184
#
#     Variable X5 has 3 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.762
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.424
#         (X6 -1): max_pval = 0.00439, |min_val| =  0.207
#
#     Variable X6 has 5 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.709
#         (X7 -1): max_pval = 0.00048, |min_val| =  0.253
#         (X6 -2): max_pval = 0.00122, |min_val| =  0.233
#         (X5 -1): max_pval = 0.00396, |min_val| =  0.210
#         (X5 -2): max_pval = 0.00491, |min_val| =  0.204
#
#     Variable X7 has 4 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.756
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.413
#         (X1 -2): max_pval = 0.00106, |min_val| =  0.237
#         (X5 -2): max_pval = 0.01861, |min_val| =  0.172
#
#     Variable X8 has 6 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.820
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.505
#         (X9 -1): max_pval = 0.00035, |min_val| =  0.259
#         (X7 -1): max_pval = 0.01094, |min_val| =  0.184
#         (X8 -3): max_pval = 0.01884, |min_val| =  0.170
#         (X6 -1): max_pval = 0.03357, |min_val| =  0.155
#
#     Variable X9 has 3 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.797
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.385
#         (X6 -4): max_pval = 0.04161, |min_val| =  0.149
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 11 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.844
#         (X0 -2): pval = 0.00000 | val = -0.588
#         (X0 -3): pval = 0.00000 | val =  0.336
#         (X1 -1): pval = 0.00532 | val =  0.205
#         (X7 -3): pval = 0.02083 | val =  0.170
#         (X2 -2): pval = 0.02736 | val =  0.164
#         (X9  0): pval = 0.03107 | val = -0.159 | unoriented link
#         (X7 -5): pval = 0.03540 | val =  0.155
#         (X3 -3): pval = 0.04116 | val =  0.152
#         (X1 -2): pval = 0.04268 | val =  0.150
#         (X2  0): pval = 0.04458 | val = -0.149 | unoriented link
#
#     Variable X1 has 18 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.842
#         (X1 -2): pval = 0.00000 | val = -0.643
#         (X1 -3): pval = 0.00000 | val =  0.421
#         (X0 -1): pval = 0.00000 | val = -0.362
#         (X2 -2): pval = 0.00003 | val = -0.305
#         (X2 -3): pval = 0.00005 | val = -0.298
#         (X2 -1): pval = 0.00005 | val =  0.295
#         (X1 -4): pval = 0.00177 | val =  0.229
#         (X3 -2): pval = 0.00218 | val =  0.226
#         (X0 -3): pval = 0.00328 | val =  0.216
#         (X2  0): pval = 0.00368 | val = -0.214 | unoriented link
#         (X9  0): pval = 0.00674 | val = -0.199 | unoriented link
#         (X5 -2): pval = 0.02127 | val = -0.170
#         (X4 -3): pval = 0.02416 | val =  0.167
#         (X3 -5): pval = 0.02886 | val =  0.162
#         (X8 -3): pval = 0.03248 | val =  0.159
#         (X9 -2): pval = 0.03330 | val = -0.157
#         (X3 -1): pval = 0.04385 | val =  0.150
#
#     Variable X2 has 13 link(s):
#         (X2 -1): pval = 0.00000 | val =  0.829
#         (X3 -1): pval = 0.00000 | val =  0.478
#         (X3 -2): pval = 0.00000 | val = -0.466
#         (X2 -2): pval = 0.00000 | val = -0.430
#         (X4  0): pval = 0.00008 | val = -0.290 | unoriented link
#         (X2 -3): pval = 0.00114 | val =  0.241
#         (X1  0): pval = 0.00368 | val = -0.214 | unoriented link
#         (X1 -1): pval = 0.01400 | val = -0.181
#         (X4 -2): pval = 0.02419 | val =  0.168
#         (X7 -3): pval = 0.03016 | val = -0.161
#         (X4 -1): pval = 0.03691 | val = -0.156
#         (X3 -3): pval = 0.04105 | val = -0.153
#         (X0  0): pval = 0.04458 | val = -0.149 | unoriented link
#
#     Variable X3 has 13 link(s):
#         (X3 -1): pval = 0.00000 | val =  0.861
#         (X3 -2): pval = 0.00000 | val = -0.607
#         (X2 -1): pval = 0.00000 | val = -0.357
#         (X4 -1): pval = 0.00001 | val =  0.324
#         (X5  0): pval = 0.00012 | val = -0.282 | unoriented link
#         (X3 -3): pval = 0.00016 | val =  0.277
#         (X3 -4): pval = 0.00238 | val =  0.225
#         (X6  0): pval = 0.00314 | val =  0.219 | unoriented link
#         (X3 -5): pval = 0.01382 | val =  0.183
#         (X6 -1): pval = 0.02024 | val =  0.173
#         (X5 -2): pval = 0.02330 | val =  0.168
#         (X4 -2): pval = 0.02664 | val = -0.165
#         (X5 -4): pval = 0.02791 | val = -0.163
#
#     Variable X4 has 10 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.849
#         (X4 -2): pval = 0.00000 | val = -0.656
#         (X4 -3): pval = 0.00000 | val =  0.553
#         (X4 -4): pval = 0.00000 | val = -0.375
#         (X2  0): pval = 0.00008 | val = -0.290 | unoriented link
#         (X4 -5): pval = 0.00025 | val = -0.270
#         (X5 -1): pval = 0.00040 | val =  0.259
#         (X5 -2): pval = 0.01020 | val = -0.190
#         (X8 -4): pval = 0.01836 | val =  0.176
#         (X2 -3): pval = 0.02472 | val = -0.168
#
#     Variable X5 has 21 link(s):
#         (X5 -1): pval = 0.00000 | val =  0.859
#         (X5 -2): pval = 0.00000 | val = -0.545
#         (X6 -1): pval = 0.00000 | val =  0.449
#         (X5 -3): pval = 0.00000 | val =  0.357
#         (X6 -3): pval = 0.00000 | val = -0.346
#         (X3 -2): pval = 0.00000 | val = -0.337
#         (X6 -2): pval = 0.00000 | val = -0.331
#         (X3 -3): pval = 0.00011 | val = -0.282
#         (X3  0): pval = 0.00012 | val = -0.282 | unoriented link
#         (X7 -2): pval = 0.00111 | val =  0.239
#         (X8 -3): pval = 0.00294 | val =  0.220
#         (X6 -4): pval = 0.00339 | val = -0.216
#         (X9 -5): pval = 0.00886 | val = -0.192
#         (X5 -4): pval = 0.00994 | val =  0.190
#         (X3 -1): pval = 0.01084 | val = -0.188
#         (X3 -4): pval = 0.01371 | val = -0.182
#         (X1 -5): pval = 0.02515 | val =  0.165
#         (X0 -4): pval = 0.03407 | val =  0.156
#         (X7 -3): pval = 0.04260 | val =  0.150
#         (X8 -2): pval = 0.04699 | val =  0.148
#         (X5 -5): pval = 0.04713 | val =  0.147
#
#     Variable X6 has 16 link(s):
#         (X6 -1): pval = 0.00000 | val =  0.863
#         (X6 -2): pval = 0.00000 | val = -0.584
#         (X5 -1): pval = 0.00000 | val = -0.436
#         (X6 -3): pval = 0.00000 | val =  0.392
#         (X5 -2): pval = 0.00014 | val =  0.278
#         (X5 -5): pval = 0.00082 | val = -0.246
#         (X5 -4): pval = 0.00142 | val = -0.235
#         (X6 -4): pval = 0.00238 | val =  0.225
#         (X8  0): pval = 0.00261 | val = -0.223 | unoriented link
#         (X3  0): pval = 0.00314 | val =  0.219 | unoriented link
#         (X7 -4): pval = 0.00364 | val = -0.215
#         (X7 -1): pval = 0.01110 | val =  0.188
#         (X7 -3): pval = 0.01224 | val = -0.186
#         (X3 -5): pval = 0.01250 | val =  0.186
#         (X8 -2): pval = 0.01325 | val =  0.185
#         (X5 -3): pval = 0.03762 | val = -0.154
#
#     Variable X7 has 7 link(s):
#         (X7 -1): pval = 0.00000 | val =  0.793
#         (X7 -2): pval = 0.00000 | val = -0.574
#         (X7 -3): pval = 0.00000 | val =  0.425
#         (X8 -2): pval = 0.00300 | val =  0.220
#         (X6 -1): pval = 0.00866 | val = -0.194
#         (X5 -2): pval = 0.04339 | val = -0.149
#         (X7 -4): pval = 0.04559 | val =  0.148
#
#     Variable X8 has 11 link(s):
#         (X8 -1): pval = 0.00000 | val =  0.832
#         (X8 -2): pval = 0.00000 | val = -0.448
#         (X9 -1): pval = 0.00000 | val =  0.395
#         (X9 -3): pval = 0.00087 | val = -0.245
#         (X6  0): pval = 0.00261 | val = -0.223 | unoriented link
#         (X6 -1): pval = 0.00990 | val = -0.192
#         (X8 -3): pval = 0.01430 | val =  0.183
#         (X9 -2): pval = 0.01982 | val = -0.173
#         (X5 -1): pval = 0.02638 | val =  0.165
#         (X6 -3): pval = 0.04405 | val =  0.151
#         (X9 -4): pval = 0.04821 | val = -0.147
#
#     Variable X9 has 12 link(s):
#         (X9 -1): pval = 0.00000 | val =  0.869
#         (X9 -2): pval = 0.00000 | val = -0.714
#         (X9 -3): pval = 0.00000 | val =  0.482
#         (X9 -4): pval = 0.00000 | val =  0.352
#         (X8 -1): pval = 0.00000 | val = -0.347
#         (X0 -2): pval = 0.00000 | val =  0.339
#         (X0 -4): pval = 0.00280 | val = -0.219
#         (X1 -1): pval = 0.00288 | val = -0.219
#         (X8 -3): pval = 0.00341 | val =  0.216
#         (X1  0): pval = 0.00674 | val = -0.199 | unoriented link
#         (X7 -4): pval = 0.02545 | val = -0.165
#         (X0  0): pval = 0.03107 | val = -0.159 | unoriented link
# AUROC for datasets/lorenz/F10/time200/lorenz-594-F10-200.npz: 0.8704166666666666
# Saved results to output/results/lorenz/F10/time200/lorenz-594-F10-200_results.npz
# Processing datasets/lorenz/F10/time200/lorenz-618-F10-200.npz...
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 5 link(s):
#         (X0 -1): max_pval = 0.00000, |min_val| =  0.852
#         (X0 -2): max_pval = 0.00000, |min_val| =  0.528
#         (X7 -5): max_pval = 0.00000, |min_val| =  0.347
#         (X0 -3): max_pval = 0.00120, |min_val| =  0.233
#         (X6 -5): max_pval = 0.01126, |min_val| =  0.185
#
#     Variable X1 has 6 link(s):
#         (X1 -1): max_pval = 0.00000, |min_val| =  0.755
#         (X1 -2): max_pval = 0.00000, |min_val| =  0.447
#         (X2 -1): max_pval = 0.00323, |min_val| =  0.214
#         (X9 -1): max_pval = 0.00677, |min_val| =  0.197
#         (X8 -5): max_pval = 0.02713, |min_val| =  0.162
#         (X1 -3): max_pval = 0.02814, |min_val| =  0.159
#
#     Variable X2 has 5 link(s):
#         (X2 -1): max_pval = 0.00000, |min_val| =  0.854
#         (X2 -2): max_pval = 0.00000, |min_val| =  0.563
#         (X2 -3): max_pval = 0.00001, |min_val| =  0.322
#         (X3 -1): max_pval = 0.00224, |min_val| =  0.222
#         (X9 -5): max_pval = 0.02490, |min_val| =  0.163
#
#     Variable X3 has 6 link(s):
#         (X3 -1): max_pval = 0.00000, |min_val| =  0.854
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.524
#         (X3 -3): max_pval = 0.00593, |min_val| =  0.199
#         (X4 -1): max_pval = 0.02671, |min_val| =  0.163
#         (X2 -3): max_pval = 0.03158, |min_val| =  0.157
#         (X1 -1): max_pval = 0.04641, |min_val| =  0.146
#
#     Variable X4 has 6 link(s):
#         (X4 -1): max_pval = 0.00000, |min_val| =  0.837
#         (X4 -2): max_pval = 0.00000, |min_val| =  0.496
#         (X1 -5): max_pval = 0.00120, |min_val| =  0.236
#         (X2 -2): max_pval = 0.00202, |min_val| =  0.225
#         (X4 -3): max_pval = 0.00842, |min_val| =  0.191
#         (X7 -4): max_pval = 0.02635, |min_val| =  0.163
#
#     Variable X5 has 3 link(s):
#         (X5 -1): max_pval = 0.00000, |min_val| =  0.830
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.459
#         (X8 -1): max_pval = 0.04834, |min_val| =  0.144
#
#     Variable X6 has 5 link(s):
#         (X6 -1): max_pval = 0.00000, |min_val| =  0.853
#         (X6 -2): max_pval = 0.00000, |min_val| =  0.527
#         (X7 -1): max_pval = 0.00083, |min_val| =  0.242
#         (X2 -2): max_pval = 0.00139, |min_val| =  0.230
#         (X6 -3): max_pval = 0.00240, |min_val| =  0.219
#
#     Variable X7 has 4 link(s):
#         (X7 -1): max_pval = 0.00000, |min_val| =  0.783
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.487
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.341
#         (X7 -3): max_pval = 0.03652, |min_val| =  0.152
#
#     Variable X8 has 4 link(s):
#         (X8 -1): max_pval = 0.00000, |min_val| =  0.813
#         (X8 -2): max_pval = 0.00000, |min_val| =  0.435
#         (X5 -5): max_pval = 0.00043, |min_val| =  0.256
#         (X6 -4): max_pval = 0.02954, |min_val| =  0.160
#
#     Variable X9 has 7 link(s):
#         (X9 -1): max_pval = 0.00000, |min_val| =  0.752
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.377
#         (X0 -1): max_pval = 0.00027, |min_val| =  0.263
#         (X7 -3): max_pval = 0.01782, |min_val| =  0.172
#         (X0 -2): max_pval = 0.02529, |min_val| =  0.163
#         (X6 -5): max_pval = 0.03299, |min_val| =  0.157
#         (X4 -1): max_pval = 0.04721, |min_val| =  0.146
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 14 link(s):
#         (X0 -1): pval = 0.00000 | val =  0.886
#         (X0 -2): pval = 0.00000 | val = -0.676
#         (X0 -3): pval = 0.00000 | val =  0.498
#         (X0 -4): pval = 0.00001 | val = -0.331
#         (X1 -1): pval = 0.00169 | val =  0.233
#         (X2  0): pval = 0.00165 | val = -0.233 | unoriented link
#         (X2 -1): pval = 0.00247 | val = -0.224
#         (X1  0): pval = 0.00592 | val = -0.205 | unoriented link
#         (X0 -5): pval = 0.00689 | val = -0.201
#         (X8 -4): pval = 0.00882 | val =  0.194
#         (X1 -2): pval = 0.01220 | val =  0.187
#         (X3 -1): pval = 0.01847 | val = -0.176
#         (X9 -1): pval = 0.01840 | val = -0.176
#         (X9  0): pval = 0.02001 | val = -0.173 | unoriented link
#
#     Variable X1 has 13 link(s):
#         (X1 -1): pval = 0.00000 | val =  0.853
#         (X1 -2): pval = 0.00000 | val = -0.655
#         (X1 -3): pval = 0.00000 | val =  0.493
#         (X1 -4): pval = 0.00000 | val = -0.346
#         (X2 -1): pval = 0.00006 | val =  0.296
#         (X8 -5): pval = 0.00026 | val =  0.269
# ...
#         (X8 -3): pval = 0.00140 | val =  0.102
#         (X2 -2): pval = 0.00427 | val =  0.092
#         (X2 -3): pval = 0.00673 | val =  0.087
#         (X3 -3): pval = 0.00924 | val =  0.083
#         (X0 -3): pval = 0.01371 | val =  0.079
#         (X8 -1): pval = 0.01927 | val =  0.075
#         (X5 -2): pval = 0.03545 | val =  0.067
#
#     Variable X3 has 8 link(s):
#         (X0 -2): pval = 0.00083 | val =  0.107
#         (X5 -1): pval = 0.00249 | val =  0.097
#         (X5 -3): pval = 0.00428 | val =  0.092
#         (X6 -3): pval = 0.00517 | val =  0.090
#         (X6 -2): pval = 0.00781 | val =  0.085
#         (X3 -1): pval = 0.01466 | val =  0.078
#         (X0 -3): pval = 0.01889 | val =  0.075
#         (X8 -1): pval = 0.03493 | val =  0.068
#
#     Variable X4 has 11 link(s):
#         (X4 -1): pval = 0.00000 | val =  0.160
#         (X6 -2): pval = 0.00206 | val =  0.099
#         (X4 -2): pval = 0.00657 | val =  0.087
#         (X3 -4): pval = 0.00708 | val =  0.086
#         (X0 -2): pval = 0.01100 | val =  0.081
#         (X4 -3): pval = 0.01566 | val =  0.078
#         (X7 -1): pval = 0.01634 | val =  0.077
#         (X5 -4): pval = 0.02180 | val =  0.074
#         (X6 -3): pval = 0.03405 | val =  0.068
#         (X0 -3): pval = 0.03758 | val =  0.067
#         (X8 -4): pval = 0.03773 | val =  0.067
#
#     Variable X5 has 13 link(s):
#         (X5 -2): pval = 0.00003 | val =  0.135
#         (X5 -3): pval = 0.00014 | val =  0.122
#         (X4 -1): pval = 0.00016 | val =  0.121
#         (X1 -1): pval = 0.00121 | val =  0.104
#         (X4 -2): pval = 0.00128 | val =  0.103
#         (X0 -3): pval = 0.00211 | val =  0.099
#         (X1 -2): pval = 0.00360 | val =  0.093
#         (X0 -2): pval = 0.00473 | val =  0.091
#         (X7 -5): pval = 0.01027 | val = -0.082
#         (X8  0): pval = 0.01690 | val = -0.077 | unoriented link
#         (X5 -1): pval = 0.03327 | val =  0.068
#         (X1 -3): pval = 0.04590 | val =  0.064
#         (X7 -4): pval = 0.04866 | val =  0.063
#
#     Variable X6 has 8 link(s):
#         (X1 -1): pval = 0.00001 | val =  0.141
#         (X9 -3): pval = 0.00002 | val =  0.135
#         (X8 -1): pval = 0.00009 | val =  0.126
#         (X6 -1): pval = 0.00054 | val =  0.111
#         (X6 -2): pval = 0.00392 | val =  0.092
#         (X6 -3): pval = 0.00460 | val =  0.091
#         (X9 -1): pval = 0.00807 | val =  0.085
#         (X8 -2): pval = 0.00995 | val =  0.083
#
#     Variable X7 has 11 link(s):
#         (X8 -1): pval = 0.00012 | val =  0.123
#         (X7 -3): pval = 0.00043 | val =  0.113
#         (X0 -3): pval = 0.00095 | val =  0.106
#         (X0 -2): pval = 0.00146 | val =  0.102
#         (X5 -1): pval = 0.00164 | val =  0.101
#         (X5 -3): pval = 0.00291 | val =  0.095
#         (X7 -1): pval = 0.00937 | val =  0.083
#         (X0 -1): pval = 0.02211 | val =  0.073
#         (X7 -2): pval = 0.02883 | val =  0.070
#         (X2 -2): pval = 0.03303 | val = -0.068
#         (X0 -5): pval = 0.04417 | val =  0.065
#
#     Variable X8 has 11 link(s):
#         (X5 -2): pval = 0.00130 | val =  0.103
#         (X5 -3): pval = 0.00139 | val =  0.102
#         (X8 -3): pval = 0.00239 | val =  0.097
#         (X3 -1): pval = 0.01254 | val =  0.080
#         (X3 -3): pval = 0.01338 | val =  0.079
#         (X5 -1): pval = 0.01473 | val =  0.078
#         (X8 -2): pval = 0.01573 | val =  0.077
#         (X5  0): pval = 0.01690 | val = -0.077 | unoriented link
#         (X4 -2): pval = 0.01949 | val =  0.075
#         (X4 -3): pval = 0.02020 | val =  0.075
#         (X8 -4): pval = 0.04940 | val =  0.063
#
#     Variable X9 has 13 link(s):
#         (X2 -3): pval = 0.00000 | val =  0.159
#         (X0 -3): pval = 0.00003 | val =  0.134
#         (X9 -1): pval = 0.00102 | val =  0.105
#         (X9 -3): pval = 0.00347 | val =  0.094
#         (X7 -3): pval = 0.00435 | val =  0.091
#         (X8 -5): pval = 0.00495 | val =  0.090
#         (X0  0): pval = 0.00834 | val =  0.084 | unoriented link
#         (X8 -3): pval = 0.01173 | val = -0.081
#         (X7 -1): pval = 0.01303 | val =  0.079
#         (X2 -1): pval = 0.02195 | val =  0.073
#         (X3 -5): pval = 0.03533 | val =  0.068
#         (X6 -5): pval = 0.04667 | val =  0.064
#         (X2 -2): pval = 0.04973 | val =  0.063
# AUROC for datasets/var/lag3-sp4/time1000/var3-671-4-0-1000.npz: 0.42083333333333334
# Saved results to output/results/var/lag3-sp4/time1000/var3-671-4-0-1000_results.npz
# Processing datasets/var/lag3-sp4/time1000/var3-981-4-0-1000.npz...
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable X0 has 10 link(s):
#         (X9 -2): max_pval = 0.00007, |min_val| =  0.126
#         (X5 -3): max_pval = 0.00010, |min_val| =  0.124
#         (X1 -1): max_pval = 0.00025, |min_val| =  0.117
#         (X0 -1): max_pval = 0.00039, |min_val| =  0.113
#         (X0 -3): max_pval = 0.00152, |min_val| =  0.101
#         (X5 -1): max_pval = 0.00202, |min_val| =  0.098
#         (X5 -2): max_pval = 0.00267, |min_val| =  0.096
#         (X1 -3): max_pval = 0.00527, |min_val| =  0.089
#         (X9 -1): max_pval = 0.00574, |min_val| =  0.088
#         (X0 -2): max_pval = 0.01779, |min_val| =  0.076
#
#     Variable X1 has 10 link(s):
#         (X1 -2): max_pval = 0.00022, |min_val| =  0.118
#         (X1 -1): max_pval = 0.00024, |min_val| =  0.117
#         (X6 -1): max_pval = 0.00150, |min_val| =  0.101
#         (X3 -3): max_pval = 0.00315, |min_val| =  0.094
#         (X3 -1): max_pval = 0.00612, |min_val| =  0.087
#         (X9 -1): max_pval = 0.01738, |min_val| =  0.076
#         (X6 -2): max_pval = 0.01907, |min_val| =  0.075
#         (X9 -3): max_pval = 0.02965, |min_val| =  0.069
#         (X8 -5): max_pval = 0.03290, |min_val| =  0.068
#         (X9 -5): max_pval = 0.04626, |min_val| =  0.064
#
#     Variable X2 has 10 link(s):
#         (X9 -3): max_pval = 0.00003, |min_val| =  0.134
#         (X1 -2): max_pval = 0.00009, |min_val| =  0.125
#         (X0 -2): max_pval = 0.00063, |min_val| =  0.109
#         (X2 -2): max_pval = 0.00166, |min_val| =  0.100
#         (X1 -1): max_pval = 0.00185, |min_val| =  0.099
#         (X2 -1): max_pval = 0.00268, |min_val| =  0.096
#         (X0 -1): max_pval = 0.01000, |min_val| =  0.082
#         (X1 -3): max_pval = 0.01647, |min_val| =  0.077
#         (X9 -2): max_pval = 0.01893, |min_val| =  0.075
#         (X2 -3): max_pval = 0.04605, |min_val| =  0.064
#
#     Variable X3 has 9 link(s):
#         (X7 -2): max_pval = 0.00000, |min_val| =  0.152
#         (X3 -3): max_pval = 0.00004, |min_val| =  0.130
#         (X0 -1): max_pval = 0.00005, |min_val| =  0.129
#         (X0 -3): max_pval = 0.00008, |min_val| =  0.126
#         (X5 -3): max_pval = 0.00017, |min_val| =  0.120
#         (X5 -2): max_pval = 0.00043, |min_val| =  0.112
#         (X0 -2): max_pval = 0.00298, |min_val| =  0.095
#         (X7 -3): max_pval = 0.00323, |min_val| =  0.094
#         (X5 -1): max_pval = 0.01983, |min_val| =  0.074
#
#     Variable X4 has 9 link(s):
#         (X3 -2): max_pval = 0.00005, |min_val| =  0.130
#         (X9 -1): max_pval = 0.00008, |min_val| =  0.125
#         (X4 -1): max_pval = 0.00019, |min_val| =  0.119
#         (X4 -3): max_pval = 0.00070, |min_val| =  0.108
#         (X6 -1): max_pval = 0.00195, |min_val| =  0.099
#         (X6 -2): max_pval = 0.00334, |min_val| =  0.094
#         (X4 -2): max_pval = 0.00421, |min_val| =  0.091
#         (X3 -3): max_pval = 0.00664, |min_val| =  0.087
#         (X6 -5): max_pval = 0.02492, |min_val| =  0.072
#
#     Variable X5 has 10 link(s):
#         (X9 -3): max_pval = 0.00000, |min_val| =  0.154
#         (X5 -1): max_pval = 0.00034, |min_val| =  0.114
#         (X5 -3): max_pval = 0.00086, |min_val| =  0.106
#         (X4 -2): max_pval = 0.00143, |min_val| =  0.102
#         (X4 -1): max_pval = 0.00249, |min_val| =  0.096
#         (X2 -2): max_pval = 0.00347, |min_val| =  0.093
#         (X4 -3): max_pval = 0.00609, |min_val| =  0.088
#         (X2 -1): max_pval = 0.00726, |min_val| =  0.086
#         (X9 -2): max_pval = 0.00733, |min_val| =  0.086
#         (X2 -3): max_pval = 0.00880, |min_val| =  0.084
#
#     Variable X6 has 9 link(s):
#         (X5 -2): max_pval = 0.00000, |min_val| =  0.163
#         (X6 -3): max_pval = 0.00000, |min_val| =  0.153
#         (X1 -3): max_pval = 0.00013, |min_val| =  0.122
#         (X4 -2): max_pval = 0.00030, |min_val| =  0.115
#         (X4 -3): max_pval = 0.00074, |min_val| =  0.108
#         (X1 -1): max_pval = 0.00148, |min_val| =  0.101
#         (X5 -4): max_pval = 0.01484, |min_val| =  0.078
#         (X6 -2): max_pval = 0.01625, |min_val| =  0.077
#         (X0 -5): max_pval = 0.04203, |min_val| =  0.065
#
#     Variable X7 has 9 link(s):
#         (X2 -1): max_pval = 0.00018, |min_val| =  0.119
#         (X7 -1): max_pval = 0.00021, |min_val| =  0.118
#         (X2 -3): max_pval = 0.00059, |min_val| =  0.109
#         (X1 -1): max_pval = 0.00102, |min_val| =  0.105
#         (X6 -2): max_pval = 0.00300, |min_val| =  0.095
#         (X6 -3): max_pval = 0.00652, |min_val| =  0.087
#         (X1 -3): max_pval = 0.00892, |min_val| =  0.083
#         (X7 -2): max_pval = 0.01082, |min_val| =  0.081
#         (X1 -5): max_pval = 0.02315, |min_val| =  0.072
#
#     Variable X8 has 10 link(s):
#         (X7 -3): max_pval = 0.00077, |min_val| =  0.107
#         (X4 -2): max_pval = 0.00124, |min_val| =  0.103
#         (X8 -2): max_pval = 0.00286, |min_val| =  0.095
#         (X4 -1): max_pval = 0.00514, |min_val| =  0.089
#         (X5 -3): max_pval = 0.00655, |min_val| =  0.087
#         (X0 -1): max_pval = 0.00673, |min_val| =  0.087
#         (X7 -2): max_pval = 0.00703, |min_val| =  0.086
#         (X4 -3): max_pval = 0.01026, |min_val| =  0.082
#         (X5 -2): max_pval = 0.01986, |min_val| =  0.074
#         (X8 -1): max_pval = 0.02498, |min_val| =  0.072
#
#     Variable X9 has 9 link(s):
#         (X3 -2): max_pval = 0.00000, |min_val| =  0.150
#         (X9 -2): max_pval = 0.00000, |min_val| =  0.147
#         (X3 -1): max_pval = 0.00007, |min_val| =  0.127
#         (X0 -3): max_pval = 0.00032, |min_val| =  0.115
#         (X1 -1): max_pval = 0.00090, |min_val| =  0.106
#         (X9 -5): max_pval = 0.00998, |min_val| =  0.082
#         (X1 -3): max_pval = 0.02305, |min_val| =  0.073
#         (X0 -1): max_pval = 0.04148, |min_val| =  0.065
#         (X8 -5): max_pval = 0.04189, |min_val| =  0.065
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable X0 has 13 link(s):
#         (X5 -3): pval = 0.00026 | val =  0.117
#         (X9 -2): pval = 0.00071 | val =  0.108
#         (X1 -1): pval = 0.00073 | val =  0.108
#         (X0 -1): pval = 0.00078 | val =  0.107
#         (X1 -3): pval = 0.00431 | val =  0.092
#         (X0 -3): pval = 0.00470 | val =  0.091
#         (X5 -2): pval = 0.00740 | val =  0.086
#         (X5 -1): pval = 0.00782 | val =  0.085
#         (X2  0): pval = 0.00808 | val = -0.085 | unoriented link
#         (X3 -3): pval = 0.02470 | val =  0.072
#         (X4 -2): pval = 0.02525 | val =  0.072
#         (X0 -2): pval = 0.03155 | val =  0.069
#         (X9 -1): pval = 0.04196 | val =  0.065
#
#     Variable X1 has 10 link(s):
#         (X1 -2): pval = 0.00082 | val =  0.107
#         (X1 -1): pval = 0.00108 | val =  0.105
#         (X7 -4): pval = 0.00442 | val = -0.091
#         (X3 -3): pval = 0.00502 | val =  0.090
#         (X3 -1): pval = 0.00552 | val =  0.089
#         (X6 -1): pval = 0.00720 | val =  0.086
#         (X9 -1): pval = 0.00920 | val =  0.083
#         (X1 -3): pval = 0.02607 | val =  0.071
#         (X9 -3): pval = 0.02602 | val =  0.071
#         (X6 -2): pval = 0.04120 | val =  0.065
#
#     Variable X2 has 12 link(s):
#         (X9 -3): pval = 0.00003 | val =  0.133
#         (X1 -2): pval = 0.00013 | val =  0.122
#         (X0 -2): pval = 0.00206 | val =  0.099
#         (X1 -1): pval = 0.00474 | val =  0.090
#         (X2 -2): pval = 0.00650 | val =  0.087
#         (X2 -1): pval = 0.00674 | val =  0.087
#         (X0  0): pval = 0.00808 | val = -0.085 | unoriented link
#         (X0 -1): pval = 0.01309 | val =  0.079
#         (X9 -2): pval = 0.02229 | val =  0.073
#         (X1 -3): pval = 0.02374 | val =  0.073
#         (X6 -3): pval = 0.02813 | val =  0.070
#         (X4 -4): pval = 0.04942 | val = -0.063
#
#     Variable X3 has 11 link(s):
#         (X7 -2): pval = 0.00000 | val =  0.153
#         (X0 -1): pval = 0.00002 | val =  0.135
#         (X5 -3): pval = 0.00011 | val =  0.124
#         (X3 -3): pval = 0.00018 | val =  0.120
#         (X5 -2): pval = 0.00024 | val =  0.117
#         (X0 -3): pval = 0.00032 | val =  0.115
#         (X0 -2): pval = 0.00449 | val =  0.091
#         (X9 -3): pval = 0.00507 | val = -0.090
#         (X5 -1): pval = 0.00711 | val =  0.086
#         (X7 -3): pval = 0.00822 | val =  0.085
#         (X1 -2): pval = 0.04408 | val = -0.065
#
#     Variable X4 has 9 link(s):
#         (X3 -2): pval = 0.00051 | val =  0.111
#         (X4 -3): pval = 0.00121 | val =  0.104
#         (X9 -1): pval = 0.00211 | val =  0.098
#         (X4 -1): pval = 0.00234 | val =  0.097
#         (X2 -3): pval = 0.01433 | val = -0.079
#         (X6 -2): pval = 0.01538 | val =  0.078
#         (X3 -3): pval = 0.02475 | val =  0.072
#         (X9 -2): pval = 0.03318 | val =  0.068
#         (X6 -1): pval = 0.04353 | val =  0.065
#
#     Variable X5 has 10 link(s):
#         (X9 -3): pval = 0.00000 | val =  0.148
#         (X5 -1): pval = 0.00029 | val =  0.116
#         (X5 -3): pval = 0.00069 | val =  0.109
#         (X4 -2): pval = 0.00173 | val =  0.100
#         (X4 -1): pval = 0.00187 | val =  0.100
#         (X2 -3): pval = 0.00305 | val =  0.095
#         (X2 -2): pval = 0.00404 | val =  0.092
#         (X2 -1): pval = 0.00563 | val =  0.089
#         (X4 -3): pval = 0.00653 | val =  0.087
#         (X9 -2): pval = 0.00839 | val =  0.085
#
#     Variable X6 has 11 link(s):
#         (X6 -3): pval = 0.00000 | val =  0.148
#         (X5 -2): pval = 0.00003 | val =  0.133
#         (X1 -3): pval = 0.00005 | val =  0.129
#         (X4 -2): pval = 0.00220 | val =  0.098
#         (X1 -1): pval = 0.00520 | val =  0.089
#         (X4 -3): pval = 0.00554 | val =  0.089
#         (X6 -2): pval = 0.01295 | val =  0.080
#         (X6 -5): pval = 0.01556 | val = -0.078
#         (X5 -4): pval = 0.03447 | val =  0.068
#         (X3 -5): pval = 0.03621 | val =  0.067
#         (X0 -5): pval = 0.04250 | val =  0.065
#
#     Variable X7 has 12 link(s):
#         (X6 -2): pval = 0.00069 | val =  0.109
#         (X2 -1): pval = 0.00078 | val =  0.108
#         (X2 -3): pval = 0.00166 | val =  0.101
#         (X7 -1): pval = 0.00283 | val =  0.096
#         (X1 -1): pval = 0.00360 | val =  0.093
#         (X1 -3): pval = 0.00758 | val =  0.086
#         (X6 -3): pval = 0.00877 | val =  0.084
#         (X7 -2): pval = 0.01149 | val =  0.081
#         (X9 -1): pval = 0.02316 | val = -0.073
#         (X2 -5): pval = 0.02474 | val = -0.072
#         (X3 -2): pval = 0.02548 | val =  0.072
#         (X1 -5): pval = 0.03580 | val =  0.067
#
#     Variable X8 has 11 link(s):
#         (X4 -2): pval = 0.00023 | val =  0.118
#         (X0 -1): pval = 0.00052 | val =  0.111
#         (X7 -3): pval = 0.00090 | val =  0.106
#         (X4 -1): pval = 0.00205 | val =  0.099
#         (X5 -3): pval = 0.00657 | val =  0.087
#         (X7 -2): pval = 0.00942 | val =  0.083
#         (X4 -3): pval = 0.01283 | val =  0.080
#         (X8 -2): pval = 0.01529 | val =  0.078
#         (X8 -1): pval = 0.02689 | val =  0.071
#         (X5 -2): pval = 0.03616 | val =  0.067
#         (X3 -3): pval = 0.04628 | val =  0.064
#
#     Variable X9 has 8 link(s):
#         (X3 -2): pval = 0.00001 | val =  0.144
#         (X9 -2): pval = 0.00002 | val =  0.136
#         (X0 -3): pval = 0.00055 | val =  0.111
#         (X3 -1): pval = 0.00095 | val =  0.106
#         (X1 -1): pval = 0.00201 | val =  0.099
#         (X9 -5): pval = 0.00595 | val =  0.088
#         (X8 -5): pval = 0.03970 | val =  0.066
#         (X1 -3): pval = 0.04473 | val =  0.064
# AUROC for datasets/var/lag3-sp4/time1000/var3-981-4-0-1000.npz: 0.5616666666666666
# Saved results to output/results/var/lag3-sp4/time1000/var3-981-4-0-1000_results.npz

# %%
import os

print(os.getcwd())
# Out:
# /root/autodl-tmp/tigramite
